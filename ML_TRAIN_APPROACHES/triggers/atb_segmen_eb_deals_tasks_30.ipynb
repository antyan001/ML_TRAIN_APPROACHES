# %%
import os
import sys
sys.path.append('./../support_library/')

# %%
import re
import numpy as np
import pandas as pd
import gc
import cx_Oracle
from cx_Oracle import makedsn 
import loader as load
import ast
import tqdm
from tqdm import tqdm_notebook

# %%
import warnings
warnings.filterwarnings('ignore')

# from support_library.plot_support import *
pd.set_option('display.max_columns', None)

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# %%
folder='data'

# %%
if not os.path.exists(os.path.join('./',folder)):
    os.makedirs(os.path.join('./',folder))

# %%
ld=load.Loader(init_dsn=True)

# %%
db_name='atb_segmen_eb_deals_tasks_ext'
file_name=db_name + '.csv'
sql='select /*+parallel(10)*/ * from '
query=sql + db_name

# %% [markdown]
# ## Working with task datamart

# %%
ld.save_csv(query=query,path=os.path.join(folder,file_name), compress=9)
# Out:
# Connecting...
# Getting data ...
# Downloaded 10,000 lines,       3sec. passed
# Downloaded 20,000 lines,       6sec. passed
# Downloaded 30,000 lines,       8sec. passed
# Downloaded 40,000 lines,      12sec. passed
# Downloaded 50,000 lines,      14sec. passed
# Downloaded 60,000 lines,      17sec. passed
# Downloaded 70,000 lines,      19sec. passed
# Downloaded 80,000 lines,      21sec. passed
# Downloaded 90,000 lines,      23sec. passed
# Downloaded 100,000 lines,      25sec. passed
# Downloaded 110,000 lines,      27sec. passed
# Downloaded 120,000 lines,      30sec. passed
# Downloaded 130,000 lines,      32sec. passed
# Downloaded 140,000 lines,      35sec. passed
# Downloaded 150,000 lines,      38sec. passed
# Downloaded 160,000 lines,      41sec. passed
# Downloaded 170,000 lines,      43sec. passed
# Downloaded 180,000 lines,      47sec. passed
# Downloaded 190,000 lines,      49sec. passed
# Downloaded 200,000 lines,      52sec. passed
# ...

# %%
df_t = pd.read_csv(os.path.join(folder,file_name), sep=';',  encoding='cp1251', compression='gzip')
# Out:
# /opt/cloudera/parcels/PYENV.ZNO20008661/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (20,26,30,31,39,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Working with deals datamart

# %%
db_name='all_camp_deals_atb_seg_eb_deep'
file_name=db_name + '.csv'
sql='select /*+parallel(20)*/ * from '
query=sql + db_name

# %%
ld.save_csv(query=query,path=os.path.join(folder,file_name), compress=9)
# Out:
# Connecting...
# Getting data ...
# Downloaded 10,000 lines,       1sec. passed
# Downloaded 20,000 lines,       2sec. passed
# Downloaded 30,000 lines,       4sec. passed
# Downloaded 40,000 lines,       5sec. passed
# Downloaded 50,000 lines,       6sec. passed
# Downloaded 60,000 lines,       7sec. passed
# Downloaded 70,000 lines,       9sec. passed
# Downloaded 80,000 lines,      10sec. passed
# Downloaded 90,000 lines,      11sec. passed
# Downloaded 100,000 lines,      13sec. passed
# Downloaded 110,000 lines,      14sec. passed
# Downloaded 120,000 lines,      15sec. passed
# Downloaded 130,000 lines,      17sec. passed
# Downloaded 140,000 lines,      18sec. passed
# Downloaded 150,000 lines,      19sec. passed
# Downloaded 160,000 lines,      21sec. passed
# Downloaded 170,000 lines,      22sec. passed
# Downloaded 180,000 lines,      24sec. passed
# Downloaded 190,000 lines,      25sec. passed
# Downloaded 200,000 lines,      26sec. passed
# ...

# %%
df_d = pd.read_csv(os.path.join(folder,file_name), sep=';',  encoding='cp1251', compression='gzip')

# %%
len(df_t), len(df_d)
# Out:
# (6293437, 235262)
