# %%
import sys
sys.path.insert(0, '/home/ektov-av/python35-libs/lib/python3.5/site-packages/') 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import calendar
import time
import os
import joblib
import warnings
    
from sklearn.preprocessing import LabelEncoder, binarize

warnings.filterwarnings('ignore')

# from support_library.plot_support import *
pd.set_option('display.max_columns', None)

# %matplotlib inline
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# %%
def add_months(date, months):
    month = date.month - 1 + months
    year = date.year + month // 12
    month = month % 12 + 1
    day = min(date.day, calendar.monthrange(year, month)[1])
    return datetime.date(year, month, day)

# %%
def get_path(folder, file):
    return os.path.join(folder, file)

# %%
folder='data_csv/deal'
postfix='_mmb' #'_mmb'

# %% [markdown]
# ## Assign FLAG to a specified value depending on the problem kind:
# ### -- set to 'test/train' if we want to generate a dataset with target variable
# ### -- set to 'validate' if we gonna check a prediction on the validation dataset

# %%
FLAG='validate' # 'test/train'

# %% [markdown]
# ## Fetching Main-Mart Database

# %%
df_columns_dict={}

# %%
if FLAG == 'test/train':
    df_kp_deal = pd.read_csv(get_path(folder, 'cvm_kp_deal_upd' + postfix + '.csv'), sep=';', 
                                                             compression='gzip', encoding='cp1251')
elif FLAG == 'validate':
    df_kp_deal = pd.read_csv(get_path(folder, 'cvm_vw_kp_deal' + '.csv'), sep=';', 
                                                             compression='gzip', encoding='cp1251')

# %%
# df_kp_deal = df_kp_deal.rename(columns={'Unnamed: 0': 'IS_SOLD'})
df_kp_deal.columns = df_kp_deal.columns.map(lambda x: x.lower())
df_kp_deal.loc[:, 'date_create'] = pd.to_datetime(df_kp_deal['date_create'], format='%Y-%m-%d')
df_kp_deal.loc[:, 'date_close']  = pd.to_datetime(df_kp_deal['date_close'], format='%Y-%m-%d')
df_kp_deal.head()

# %%
df_kp_deal.duplicated(subset=['inn', 'id']).sum()
#df_kp_deal = df_kp_deal.drop_duplicates()
# Out:
# 0

# %%
df_kp_deal.shape
# Out:
# (19860, 18)

# %%
data=df_kp_deal

# %%
if FLAG == 'test/train':
    ckp_filter = data[(data['year_n']==2018) & (data['month_n']>0) & (data['ckp']=='ЦА-КРЕДСМАРТ')]
    pr_gr = pd.concat([pd.DataFrame(ckp_filter.groupby(['ckp','year_n', 'month_n'])['is_sold'].count())
                      ,pd.DataFrame(ckp_filter[ckp_filter['is_sold']==1].groupby(['ckp','year_n', 'month_n'])['is_sold'].count())
                      ,pd.DataFrame(ckp_filter[ckp_filter['is_sold']==0].groupby(['ckp','year_n', 'month_n'])['is_sold'].count())
                      ,], axis=1)
    pr_gr.columns=['TOTAL', '1', '0']
    pr_gr.head(20)

# %%
if FLAG == 'test/train':    
    balance = pd.concat([df_kp_deal.groupby('product_group')['is_sold'].sum(), 
                         df_kp_deal.groupby('product_group')['is_sold'].count()], axis=1)
    balance.columns = ['Sum of sold', 'Count']
    balance['balance'] = balance['Sum of sold'] / balance['Count']*100
    balance = balance.sort_values('balance', ascending=False)
    balance

# %%
if FLAG == 'test/train':
    df_temp = df_kp_deal[['date_create', 'is_sold']]
    df_temp = df_temp.set_index('date_create')
    df_temp.groupby(pd.Grouper(freq='M'))['is_sold'].count().sort_index().plot(kind='bar', color='orange', figsize=(10,8))

# %%
df_columns_dict['df_kp_deal']=df_kp_deal.columns.tolist()

# %% [markdown]
# ## Working with Client Managers' database. Historic Data over CM

# %%
df_kp_km = pd.read_csv(get_path(folder, 'cvm_kp_km_upd' + postfix + '.csv'), sep=';', 
                                                         compression='gzip', encoding='cp1251')

# %%
# df_kp_km = df_kp_km.rename(columns={'Unnamed: 0': 'MONTH_'})
df_kp_km.columns = df_kp_km.columns.map(lambda x: x.lower())
df_kp_km.loc[:, 'month_'] = pd.to_datetime(df_kp_km['month_'], format='%Y-%m-%d')
df_kp_km = df_kp_km.drop(['year_n', 'month_n'], axis = 1)
df_kp_km.head()

# %%
df_kp_km.sort_values('month_').groupby(['month_']).sum()

# %%
df_temp = df_kp_km[['month_', 'sum_sold']]
df_temp = df_temp.set_index('month_')
df_temp.groupby(pd.Grouper(freq='M'))['sum_sold'].sum().sort_index().plot(kind='bar', color='orange', figsize=(10,8))

# %%
df_kp_km.isnull().sum()
# Out:
# month_                         0
# vko_id                       160
# product                        0
# product_group                  0
# sum_sold                       0
# sum_sold_cumulate              0
# sum_refused                    0
# sum_refused_cumulate           0
# sum_sold_total               160
# sum_sold_total_cumulate      160
# sum_refused_total            160
# sum_refused_tota_cumulate    160
# dtype: int64

# %%
df_kp_km.shape
# Out:
# (1170704, 12)

# %%
df_kp_km = df_kp_km[~df_kp_km['vko_id'].isnull()]

# %%
df_kp_km=df_kp_km.drop_duplicates()

# %%
df_kp_km.shape
# Out:
# (1170544, 12)

# %%
df_columns_dict['df_kp_deal']=df_kp_deal.columns.tolist()

# %% [markdown]
# ## Treatment of Historic Data over Companies

# %%
df_kp_company = pd.read_csv(get_path(folder, 'cvm_kp_company_upd' + postfix + '.csv'), sep=';', 
                                                         compression='gzip', encoding='cp1251')

# %%
df_kp_company.shape
# Out:
# (6135408, 14)

# %%
# df_kp_company=df_kp_company.rename(columns={'Unnamed: 0': 'MONTH_'})
df_kp_company.columns = df_kp_company.columns.map(lambda x: x.lower())
df_kp_company = df_kp_company.drop(['year_n', 'month_n'], axis = 1)
df_kp_company.loc[:, 'month_'] = pd.to_datetime(df_kp_company['month_'], format='%Y-%m-%d')
df_kp_company.head()

# %%
df_kp_company.sort_values('month_').groupby(['month_']).sum()

# %%
df_temp = df_kp_company[['month_', 'sum_sold']]
df_temp = df_temp.set_index('month_')
df_temp.groupby(pd.Grouper(freq='M'))['sum_sold'].sum().sort_index().plot(kind='bar', color='blue', figsize=(10,8))

# %%
df_kp_company.isnull().sum()
# Out:
# month_                        0
# company_id                    0
# product                       0
# product_group                 0
# sum_sold                      0
# sum_sold_cumulate             0
# sum_refused                   0
# sum_refused_cumulate          0
# sum_sold_total                0
# sum_sold_total_cumulate       0
# sum_refused_total             0
# sum_refused_total_cumulate    0
# dtype: int64

# %%
df_kp_company.shape
# Out:
# (6135408, 12)

# %%
df_kp_company=df_kp_company.drop_duplicates()

# %%
df_kp_company.shape
# Out:
# (6135185, 12)

# %%
df_kp_company.duplicated(subset=['month_', 'company_id', 'product']).sum()
# Out:
# 49

# %%
df_columns_dict['df_kp_company']=df_kp_company.columns.tolist()

# %% [markdown]
# ## Aggregates

# %%
df_kp_km_aggregates = df_kp_km.groupby(['vko_id', 'month_', 'product_group']).sum().reset_index()
df_kp_km_aggregates.head()

# %%
df_kp_company_aggregates = df_kp_company.groupby(['company_id', 'month_', 'product_group']).sum().reset_index()

# %%
df_columns_dict['df_kp_km_aggregates']=df_kp_km_aggregates.columns.tolist()
df_columns_dict['df_kp_company_aggregates']=df_kp_company_aggregates.columns.tolist()

# %% [markdown]
# ## Aggregating statistics for Products being sold by CM

# %%
df_kp_share_prod = pd.read_csv(get_path(folder, 'cvm_kp_km_share_prod_upd' + '.csv'), sep=';', 
                                                         compression='gzip', encoding='cp1251')

# %%
# df_kp_share_prod=df_kp_share_prod.rename(columns={'Unnamed: 0': 'MONTH_'})
df_kp_share_prod.columns = df_kp_share_prod.columns.map(lambda x: x.lower())
df_kp_share_prod = df_kp_share_prod.drop(['year_n', 'month_n'], axis = 1)
df_kp_share_prod.loc[:, 'month_'] = pd.to_datetime(df_kp_share_prod['month_'], format='%Y-%m-%d')
df_kp_share_prod.head()

# %%
df_kp_share_prod.groupby(['month_']).sum()

# %%
df_kp_share_prod.groupby(['month_', 'vko_id']).sum().groupby(['month_']).sum()

# %%
df_kp_share_prod.sort_values('month_').groupby('month_')['vko_id'].count()
# Out:
# month_
# 2017-08-01    8311
# 2017-09-01    8321
# 2017-10-01    8456
# 2017-11-01    8553
# 2017-12-01    8508
# 2018-01-01    8606
# 2018-02-01    8559
# 2018-03-01    8594
# 2018-04-01    8495
# 2018-05-01    8397
# 2018-06-01    8371
# 2018-07-01    8422
# 2018-08-01    8567
# 2018-09-01    8261
# 2018-10-01    8355
# Name: vko_id, dtype: int64

# %%
df_kp_share_prod.duplicated(subset=['month_', 'vko_id']).sum()
# Out:
# 0

# %%
df_kp_share_prod.shape
# Out:
# (126791, 43)

# %%
df_kp_share_prod.isnull().sum()

# %%
for col in df_kp_share_prod.columns:
    if df_kp_share_prod[col].isnull().sum() == df_kp_share_prod.shape[0]:
        df_kp_share_prod.drop([col], axis = 1, inplace=True)
        print(col+' has been deleted')
# Out:
# obsluzh_beneficiar has been deleted
# priem_platezh has been deleted

# %%
df_kp_share_prod = df_kp_share_prod[~df_kp_share_prod['total_client_cnt'].isnull()]

# %%
df_kp_share_prod.shape
# Out:
# (126776, 41)

# %%
for col in set(df_kp_share_prod.columns) - set(['month_', 'year_n', 'month_n', 'total_client_cnt', 'vko_id']):
    df_kp_share_prod[col + '_ratio'] = df_kp_share_prod[col] / df_kp_share_prod['total_client_cnt']

# %%
df_kp_share_prod.head()

# %%
df_columns_dict['df_kp_share_prod']=df_kp_share_prod.columns.tolist()

# %% [markdown]
# ## Difference between current deal and previous one (by Companies)

# %%
df_comp_dealdiff = pd.read_csv(get_path(folder, 'cvm_kp_comp_dealdiff_upd'+ postfix +'.csv'), sep=';', 
                                                         compression='gzip', encoding='cp1251')

# %%
# df_comp_dealdiff = df_comp_dealdiff.rename(columns={'Unnamed: 0': 'company_id'})
df_comp_dealdiff.columns = df_comp_dealdiff.columns.map(lambda x: x.lower())
df_comp_dealdiff = df_comp_dealdiff.drop(['year_n', 'month_n'], axis = 1)
df_comp_dealdiff.loc[:, 'date_create'] = pd.to_datetime(df_comp_dealdiff['date_create'], format='%Y-%m-%d')
df_comp_dealdiff.head()
# Out:
#   company_id date_create  days_between  is_previous_sold
# 0  1-28MP1RP  2018-10-02            40                 0
# 1  1-28MP1RP  2018-08-23           153                 0
# 2  1-28OIKJA  2018-06-09            22                 0
# 3  1-28OIKJA  2018-05-18            72                 1
# 4  1-28Q7JHA  2018-06-07            80                 0

# %%
df_comp_dealdiff.drop_duplicates(inplace=True)

# %%
df_comp_dealdiff.shape
# Out:
# (74322, 4)

# %%
df_columns_dict['df_comp_dealdiff']=df_comp_dealdiff.columns.tolist()

# %% [markdown]
# ## Difference between current deal and previous one (by CM)

# %%
df_km_dealdiff = pd.read_csv(get_path(folder, 'cvm_kp_km_dealdiff_upd'+ postfix +'.csv'), sep=';', 
                                                         compression='gzip', encoding='cp1251')

# %%
# df_km_dealdiff = df_km_dealdiff.rename(columns={'Unnamed: 0': 'vko_id'})
df_km_dealdiff.columns = df_km_dealdiff.columns.map(lambda x: x.lower())
df_km_dealdiff = df_km_dealdiff.drop(['year_n', 'month_n'], axis = 1)
df_km_dealdiff.loc[:, 'date_create'] = pd.to_datetime(df_km_dealdiff['date_create'], format='%Y-%m-%d')
df_km_dealdiff.head()
# Out:
#       vko_id date_create  days_between  is_previous_sold
# 0  1-O1RWNL0  2018-05-10             2                 0
# 1  1-O1RWNL0  2018-05-08            15                 1
# 2  1-O1RWNL0  2018-04-23             3                 0
# 3  1-O1RWNL0  2018-04-20             2                 1
# 4  1-O1RWNL0  2018-04-09            10                 1

# %%
df_km_dealdiff.drop_duplicates(inplace=True)

# %%
df_km_dealdiff.shape
# Out:
# (142502, 4)

# %%
df_km_dealdiff.columns.tolist()
# Out:
# ['vko_id', 'date_create', 'days_between', 'is_previous_sold']

# %%
df_columns_dict['df_km_dealdiff']=df_km_dealdiff.columns.tolist()

# %%
df_columns_dict.keys()
joblib.dump(df_columns_dict, get_path('pkl_store', 'df_columns_dict.pkl'))
# Out:
# ['pkl_store/df_columns_dict.pkl']

# %% [markdown]
# ## Joining Databases with Aggregates on Main Mart Database

# %%
start_shape = df_kp_deal.shape[0]

# %%
df = df_kp_deal

# %%
df.shape
# Out:
# (19860, 18)

# %%
df['kp_prev_1'] = (pd.to_datetime({'day': 1, 'month': df['date_create'].dt.month, \
            'year': df['date_create'].dt.year}) - pd.offsets.MonthOffset(1))
df['kp_prev_2'] = (pd.to_datetime({'day': 1, 'month': df['date_create'].dt.month, \
            'year': df['date_create'].dt.year}) - pd.offsets.MonthOffset(2))
df['kp_prev_3'] = (pd.to_datetime({'day': 1, 'month': df['date_create'].dt.month, \
            'year': df['date_create'].dt.year}) - pd.offsets.MonthOffset(3))

# %%
df_kp_company.loc[df_kp_company.duplicated(['company_id', 'month_', 'product'], keep=False),:].sort_values(['company_id', 'month_', 'product'], ascending=True)

# %%
df_kp_company.drop_duplicates(['company_id', 'month_', 'product'], keep=False, inplace=True)

# %%
for i in [1,2,3]:
    print('Roll back by %.d month' % i)
    df = df.merge(   df_kp_km, how='left', left_on=['vko_id', 'kp_prev_%.d' % i, 'product'], \
                     right_on=['vko_id', 'month_', 'product'], suffixes=('', '_km_shift_%.d' % i))
    count_kp_km = df.merge(df_kp_km, how='inner', left_on=['vko_id', 'kp_prev_%.d' % i, 'product'], \
             right_on=['vko_id', 'month_', 'product']).shape[0]
    
    print('CM: Databases intersection is equal to %.d rows' % (count_kp_km))
    
    df = df.merge(  df_kp_company, how='left', left_on=['company_id', 'kp_prev_%.d' % i, 'product'], \
                    right_on=['company_id', 'month_', 'product'], suffixes=('', '_company_shift_%.d' % i))
    count_kp_company = df.merge(df_kp_company, how='inner', left_on=['company_id', 'kp_prev_%.d' % i, 'product'], \
             right_on=['company_id', 'month_', 'product']).shape[0]
    
    print('COMPANIES: Databases intersection is equal to %.d rows' % (count_kp_company))
# Out:
# Roll back by 1 month
# CM: Databases intersection is equal to 16640 rows
# COMPANIES: Databases intersection is equal to 1535 rows
# Roll back by 2 month
# CM: Databases intersection is equal to 16616 rows
# COMPANIES: Databases intersection is equal to 1529 rows
# Roll back by 3 month
# CM: Databases intersection is equal to 16593 rows
# COMPANIES: Databases intersection is equal to 1525 rows

# %%
df.head()
#df[df['sum_sold'].isnull()].head()

# %%
start_shape - df.shape[0]
# Out:
# 0

# %%
len(set(df['company_id']) - set(df_kp_deal['company_id']))
# Out:
# 0

# %% [markdown]
# ## Joining Databases with aggregates

# %%
df_kp_company_aggregates.loc[df_kp_company_aggregates.duplicated(['company_id', 'month_', 'product_group'], keep=False),:].sort_values(['company_id', 'month_', 'product_group'], ascending=True)
# Out:
# Empty DataFrame
# Columns: [company_id, month_, product_group, sum_sold, sum_sold_cumulate, sum_refused, sum_refused_cumulate, sum_sold_total, sum_sold_total_cumulate, sum_refused_total, sum_refused_total_cumulate]
# Index: []

# %%
for i in [1, 2, 3]:
    print('Roll back by %.d month' % i)
    df = df.merge(df_kp_km_aggregates, how='left', left_on=['vko_id', 'kp_prev_%.d' % i, 'product_group'], \
             right_on=['vko_id', 'month_', 'product_group'], suffixes=('', '_agg_km_shift_%.d' % i))
    count_kp_km = df.merge(df_kp_km_aggregates, how='inner', 
                             left_on =['vko_id', 'kp_prev_%.d' % i, 'product_group'], \
                             right_on=['vko_id', 'month_', 'product_group']).shape[0]
    print('CM: Databases intersection is equal to %.d rows' % (count_kp_km))
    
    df = df.merge(df_kp_company_aggregates, how='left', left_on=['company_id', 'kp_prev_%.d' % i, 'product_group'], \
             right_on=['company_id', 'month_', 'product_group'], suffixes=('', '_agg_company_shift_%.d' % i))
    count_kp_company = df.merge(df_kp_company_aggregates, how='inner', 
                                left_on=['company_id', 'kp_prev_%.d' % i, 'product_group'], \
                                right_on=['company_id', 'month_', 'product_group']).shape[0]
    print('COMPANY: Databases intersection is equal to %.d rows' % (count_kp_company))
# Out:
# Roll back by 1 month
# CM: Databases intersection is equal to 18736 rows
# COMPANY: Databases intersection is equal to 2569 rows
# Roll back by 2 month
# CM: Databases intersection is equal to 18710 rows
# COMPANY: Databases intersection is equal to 2562 rows
# Roll back by 3 month
# CM: Databases intersection is equal to 18684 rows
# COMPANY: Databases intersection is equal to 2558 rows

# %%
start_shape - df.shape[0]
# Out:
# 0

# %%
df_kp_company_aggregates['month_'].sort_values().unique()
# Out:
# array(['2017-08-01T00:00:00.000000000', '2017-09-01T00:00:00.000000000',
#        '2017-10-01T00:00:00.000000000', '2017-11-01T00:00:00.000000000',
#        '2017-12-01T00:00:00.000000000', '2018-01-01T00:00:00.000000000',
#        '2018-02-01T00:00:00.000000000', '2018-03-01T00:00:00.000000000',
#        '2018-04-01T00:00:00.000000000', '2018-05-01T00:00:00.000000000',
#        '2018-06-01T00:00:00.000000000', '2018-07-01T00:00:00.000000000',
#        '2018-08-01T00:00:00.000000000', '2018-09-01T00:00:00.000000000',
#        '2018-10-01T00:00:00.000000000', '2018-11-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %% [markdown]
# ## Joining df_kp_share_prod Database

# %%
df_kp_share_prod.shape
# Out:
# (126776, 79)

# %%
df_kp_share_prod.duplicated().sum()
# Out:
# 0

# %%
df_kp_share_prod.head()

# %%
for i in [1, 2, 3]:
    print('Roll back by %.d month' % i)
    df = df.merge(df_kp_share_prod, how='left', left_on=['vko_id', 'kp_prev_%.d' % i], \
             right_on=['vko_id', 'month_'], suffixes=('', '_share_prod_shift_%.d' % i))
    count = df.merge(df_kp_share_prod, how='inner', left_on=['vko_id', 'kp_prev_%.d' % i], \
             right_on=['vko_id', 'month_'], suffixes=('', '_share_prod_shift_%.d' % i)).shape[0]
    print('df_kp_share_prod: Databases intersection is equal to %.d rows' % (count_kp_km))
# Out:
# Roll back by 1 month
# df_kp_share_prod: Databases intersection is equal to 18684 rows
# Roll back by 2 month
# df_kp_share_prod: Databases intersection is equal to 18684 rows
# Roll back by 3 month
# df_kp_share_prod: Databases intersection is equal to 18684 rows

# %%
start_shape - df.shape[0]
# Out:
# 0

# %% [markdown]
# ## Joining cvm_kp_comp_dealdiff_mmb

# %%
df_comp_dealdiff.duplicated(['company_id', 'date_create']).sum()
# Out:
# 0

# %%
len(set(df_comp_dealdiff['company_id']) - set(df['company_id']))
# Out:
# 41501

# %%
df = df.merge(df_comp_dealdiff, how='left', on =['company_id', 'date_create'], suffixes=('', '_comp_dealdiff'))

# %%
start_shape - df.shape[0]
# Out:
# 0

# %% [markdown]
# ## Joining cvm_kp_km_dealdiff_mmb

# %%
df = df.merge(df_km_dealdiff, how='left', on=['vko_id', 'date_create'], suffixes=('', '_km_dealdiff'))

# %%
#df.shape[0] - df.merge(df_km_dealdiff, how='inner', on=['vko_id', 'date_create']).shape[0]

# %%
start_shape - df.shape[0]
# Out:
# 0

# %%
df.shape
# Out:
# (19860, 373)

# %% [markdown]
# ## Cleaning dataset

# %%
coltypes=df.dtypes.to_dict()

# %%
coltypes
# Out:
# {'acquiring_mobile': dtype('float64'),
#  'acquiring_mobile_ratio': dtype('float64'),
#  'acquiring_mobile_ratio_share_prod_shift_2': dtype('float64'),
#  'acquiring_mobile_ratio_share_prod_shift_3': dtype('float64'),
#  'acquiring_mobile_share_prod_shift_2': dtype('float64'),
#  'acquiring_mobile_share_prod_shift_3': dtype('float64'),
#  'acquiring_torg': dtype('float64'),
#  'acquiring_torg_ratio': dtype('float64'),
#  'acquiring_torg_ratio_share_prod_shift_2': dtype('float64'),
#  'acquiring_torg_ratio_share_prod_shift_3': dtype('float64'),
#  'acquiring_torg_share_prod_shift_2': dtype('float64'),
#  'acquiring_torg_share_prod_shift_3': dtype('float64'),
#  'acreditiv': dtype('float64'),
#  'acreditiv_ratio': dtype('float64'),
#  'acreditiv_ratio_share_prod_shift_2': dtype('float64'),
#  'acreditiv_ratio_share_prod_shift_3': dtype('float64'),
#  'acreditiv_share_prod_shift_2': dtype('float64'),
#  'acreditiv_share_prod_shift_3': dtype('float64'),
#  'arenda_seyf': dtype('float64'),
#  'arenda_seyf_ratio': dtype('float64'),
#  'arenda_seyf_ratio_share_prod_shift_2': dtype('float64'),
#  'arenda_seyf_ratio_share_prod_shift_3': dtype('float64'),
#  'arenda_seyf_share_prod_shift_2': dtype('float64'),
#  'arenda_seyf_share_prod_shift_3': dtype('float64'),
#  'bank_straxovanie_imush': dtype('float64'),
#  'bank_straxovanie_imush_ratio': dtype('float64'),
#  'bank_straxovanie_imush_ratio_share_prod_shift_2': dtype('float64'),
#  'bank_straxovanie_imush_ratio_share_prod_shift_3': dtype('float64'),
#  'bank_straxovanie_imush_share_prod_shift_2': dtype('float64'),
#  'bank_straxovanie_imush_share_prod_shift_3': dtype('float64'),
#  'bank_straxovanie_lich': dtype('float64'),
#  'bank_straxovanie_lich_ratio': dtype('float64'),
#  'bank_straxovanie_lich_ratio_share_prod_shift_2': dtype('float64'),
#  'bank_straxovanie_lich_ratio_share_prod_shift_3': dtype('float64'),
#  'bank_straxovanie_lich_share_prod_shift_2': dtype('float64'),
#  'bank_straxovanie_lich_share_prod_shift_3': dtype('float64'),
#  'bank_straxovanie_otvet': dtype('float64'),
#  'bank_straxovanie_otvet_ratio': dtype('float64'),
#  'bank_straxovanie_otvet_ratio_share_prod_shift_2': dtype('float64'),
#  'bank_straxovanie_otvet_ratio_share_prod_shift_3': dtype('float64'),
#  'bank_straxovanie_otvet_share_prod_shift_2': dtype('float64'),
#  'bank_straxovanie_otvet_share_prod_shift_3': dtype('float64'),
#  'cash_management': dtype('float64'),
#  'cash_management_ratio': dtype('float64'),
#  'cash_management_ratio_share_prod_shift_2': dtype('float64'),
#  'cash_management_ratio_share_prod_shift_3': dtype('float64'),
#  'cash_management_share_prod_shift_2': dtype('float64'),
#  'cash_management_share_prod_shift_3': dtype('float64'),
#  'ckp': dtype('O'),
#  'ckp_id': dtype('O'),
#  'company_id': dtype('O'),
#  'corporate_cards': dtype('float64'),
#  'corporate_cards_ratio': dtype('float64'),
#  'corporate_cards_ratio_share_prod_shift_2': dtype('float64'),
#  'corporate_cards_ratio_share_prod_shift_3': dtype('float64'),
#  'corporate_cards_share_prod_shift_2': dtype('float64'),
#  'corporate_cards_share_prod_shift_3': dtype('float64'),
#  'date_close': dtype('<M8[ns]'),
#  'date_create': dtype('<M8[ns]'),
#  'days_between': dtype('float64'),
#  'days_between_km_dealdiff': dtype('float64'),
#  'days_cr_q_end': dtype('int64'),
#  'dbo': dtype('float64'),
#  'dbo_ratio': dtype('float64'),
#  'dbo_ratio_share_prod_shift_2': dtype('float64'),
#  'dbo_ratio_share_prod_shift_3': dtype('float64'),
#  'dbo_share_prod_shift_2': dtype('float64'),
#  'dbo_share_prod_shift_3': dtype('float64'),
#  'dcd': dtype('float64'),
#  'dcd_ratio': dtype('float64'),
#  'dcd_ratio_share_prod_shift_2': dtype('float64'),
#  'dcd_ratio_share_prod_shift_3': dtype('float64'),
#  'dcd_share_prod_shift_2': dtype('float64'),
#  'dcd_share_prod_shift_3': dtype('float64'),
#  'deposit': dtype('float64'),
#  'deposit_ratio': dtype('float64'),
#  'deposit_ratio_share_prod_shift_2': dtype('float64'),
#  'deposit_ratio_share_prod_shift_3': dtype('float64'),
#  'deposit_sertificat': dtype('float64'),
#  'deposit_sertificat_ratio': dtype('float64'),
#  'deposit_sertificat_ratio_share_prod_shift_2': dtype('float64'),
#  'deposit_sertificat_ratio_share_prod_shift_3': dtype('float64'),
#  'deposit_sertificat_share_prod_shift_2': dtype('float64'),
#  'deposit_sertificat_share_prod_shift_3': dtype('float64'),
#  'deposit_share_prod_shift_2': dtype('float64'),
#  'deposit_share_prod_shift_3': dtype('float64'),
#  'einvoicing': dtype('float64'),
#  'einvoicing_ratio': dtype('float64'),
#  'einvoicing_ratio_share_prod_shift_2': dtype('float64'),
#  'einvoicing_ratio_share_prod_shift_3': dtype('float64'),
#  'einvoicing_share_prod_shift_2': dtype('float64'),
#  'einvoicing_share_prod_shift_3': dtype('float64'),
#  'factoring': dtype('float64'),
#  'factoring_ratio': dtype('float64'),
#  'factoring_ratio_share_prod_shift_2': dtype('float64'),
#  'factoring_ratio_share_prod_shift_3': dtype('float64'),
#  'factoring_share_prod_shift_2': dtype('float64'),
#  'factoring_share_prod_shift_3': dtype('float64'),
#  'garantee_gos': dtype('float64'),
#  'garantee_gos_ratio': dtype('float64'),
#  'garantee_gos_ratio_share_prod_shift_2': dtype('float64'),
#  'garantee_gos_ratio_share_prod_shift_3': dtype('float64'),
#  'garantee_gos_share_prod_shift_2': dtype('float64'),
#  'garantee_gos_share_prod_shift_3': dtype('float64'),
#  'garantee_kontract': dtype('float64'),
#  'garantee_kontract_ratio': dtype('float64'),
#  'garantee_kontract_ratio_share_prod_shift_2': dtype('float64'),
#  'garantee_kontract_ratio_share_prod_shift_3': dtype('float64'),
#  'garantee_kontract_share_prod_shift_2': dtype('float64'),
#  'garantee_kontract_share_prod_shift_3': dtype('float64'),
#  'garantee_other': dtype('float64'),
#  'garantee_other_ratio': dtype('float64'),
#  'garantee_other_ratio_share_prod_shift_2': dtype('float64'),
#  'garantee_other_ratio_share_prod_shift_3': dtype('float64'),
#  'garantee_other_share_prod_shift_2': dtype('float64'),
#  'garantee_other_share_prod_shift_3': dtype('float64'),
#  'gosb': dtype('O'),
#  'id': dtype('O'),
#  'inkass': dtype('float64'),
#  'inkass_ratio': dtype('float64'),
#  'inkass_ratio_share_prod_shift_2': dtype('float64'),
#  'inkass_ratio_share_prod_shift_3': dtype('float64'),
#  'inkass_share_prod_shift_2': dtype('float64'),
#  'inkass_share_prod_shift_3': dtype('float64'),
#  'inn': dtype('int64'),
#  'invest_kredit': dtype('float64'),
#  'invest_kredit_ratio': dtype('float64'),
#  'invest_kredit_ratio_share_prod_shift_2': dtype('float64'),
#  'invest_kredit_ratio_share_prod_shift_3': dtype('float64'),
#  'invest_kredit_share_prod_shift_2': dtype('float64'),
#  'invest_kredit_share_prod_shift_3': dtype('float64'),
#  'is_previous_sold': dtype('float64'),
#  'is_previous_sold_km_dealdiff': dtype('float64'),
#  'konversion': dtype('float64'),
#  'konversion_ratio': dtype('float64'),
#  'konversion_ratio_share_prod_shift_2': dtype('float64'),
#  'konversion_ratio_share_prod_shift_3': dtype('float64'),
#  'konversion_share_prod_shift_2': dtype('float64'),
#  'konversion_share_prod_shift_3': dtype('float64'),
#  'kp_prev_1': dtype('<M8[ns]'),
#  'kp_prev_2': dtype('<M8[ns]'),
#  'kp_prev_3': dtype('<M8[ns]'),
#  'month_': dtype('<M8[ns]'),
#  'month__agg_company_shift_1': dtype('<M8[ns]'),
#  'month__agg_company_shift_2': dtype('<M8[ns]'),
#  'month__agg_company_shift_3': dtype('<M8[ns]'),
#  'month__agg_km_shift_1': dtype('<M8[ns]'),
#  'month__agg_km_shift_2': dtype('<M8[ns]'),
#  'month__agg_km_shift_3': dtype('<M8[ns]'),
#  'month__company_shift_1': dtype('<M8[ns]'),
#  'month__company_shift_2': dtype('<M8[ns]'),
#  'month__company_shift_3': dtype('<M8[ns]'),
#  'month__km_shift_2': dtype('<M8[ns]'),
#  'month__km_shift_3': dtype('<M8[ns]'),
#  'month__share_prod_shift_1': dtype('<M8[ns]'),
#  'month__share_prod_shift_2': dtype('<M8[ns]'),
#  'month__share_prod_shift_3': dtype('<M8[ns]'),
#  'month_n': dtype('int64'),
#  'ns_garant': dtype('float64'),
#  'ns_garant_ratio': dtype('float64'),
#  'ns_garant_ratio_share_prod_shift_2': dtype('float64'),
#  'ns_garant_ratio_share_prod_shift_3': dtype('float64'),
#  'ns_garant_share_prod_shift_2': dtype('float64'),
#  'ns_garant_share_prod_shift_3': dtype('float64'),
#  'ns_sait': dtype('float64'),
#  'ns_sait_ratio': dtype('float64'),
#  'ns_sait_ratio_share_prod_shift_2': dtype('float64'),
#  'ns_sait_ratio_share_prod_shift_3': dtype('float64'),
#  'ns_sait_share_prod_shift_2': dtype('float64'),
#  'ns_sait_share_prod_shift_3': dtype('float64'),
#  'ns_servis': dtype('float64'),
#  'ns_servis_ratio': dtype('float64'),
#  'ns_servis_ratio_share_prod_shift_2': dtype('float64'),
#  'ns_servis_ratio_share_prod_shift_3': dtype('float64'),
#  'ns_servis_share_prod_shift_2': dtype('float64'),
#  'ns_servis_share_prod_shift_3': dtype('float64'),
#  'ns_terminal': dtype('float64'),
#  'ns_terminal_ratio': dtype('float64'),
#  'ns_terminal_ratio_share_prod_shift_2': dtype('float64'),
#  'ns_terminal_ratio_share_prod_shift_3': dtype('float64'),
#  'ns_terminal_share_prod_shift_2': dtype('float64'),
#  'ns_terminal_share_prod_shift_3': dtype('float64'),
#  'oborot_kredit': dtype('float64'),
#  'oborot_kredit_ratio': dtype('float64'),
#  'oborot_kredit_ratio_share_prod_shift_2': dtype('float64'),
#  'oborot_kredit_ratio_share_prod_shift_3': dtype('float64'),
#  'oborot_kredit_share_prod_shift_2': dtype('float64'),
#  'oborot_kredit_share_prod_shift_3': dtype('float64'),
#  'obsluzh_rts_rur': dtype('float64'),
#  'obsluzh_rts_rur_ratio': dtype('float64'),
#  'obsluzh_rts_rur_ratio_share_prod_shift_2': dtype('float64'),
#  'obsluzh_rts_rur_ratio_share_prod_shift_3': dtype('float64'),
#  'obsluzh_rts_rur_share_prod_shift_2': dtype('float64'),
#  'obsluzh_rts_rur_share_prod_shift_3': dtype('float64'),
#  'obsluzh_rts_val': dtype('float64'),
#  'obsluzh_rts_val_ratio': dtype('float64'),
#  'obsluzh_rts_val_ratio_share_prod_shift_2': dtype('float64'),
#  'obsluzh_rts_val_ratio_share_prod_shift_3': dtype('float64'),
#  'obsluzh_rts_val_share_prod_shift_2': dtype('float64'),
#  'obsluzh_rts_val_share_prod_shift_3': dtype('float64'),
#  'overdraft_kredit': dtype('float64'),
#  'overdraft_kredit_ratio': dtype('float64'),
#  'overdraft_kredit_ratio_share_prod_shift_2': dtype('float64'),
#  'overdraft_kredit_ratio_share_prod_shift_3': dtype('float64'),
#  'overdraft_kredit_share_prod_shift_2': dtype('float64'),
#  'overdraft_kredit_share_prod_shift_3': dtype('float64'),
#  'pfi': dtype('float64'),
#  'pfi_ratio': dtype('float64'),
#  'pfi_ratio_share_prod_shift_2': dtype('float64'),
#  'pfi_ratio_share_prod_shift_3': dtype('float64'),
#  'pfi_share_prod_shift_2': dtype('float64'),
#  'pfi_share_prod_shift_3': dtype('float64'),
#  'priority_client': dtype('O'),
#  'product': dtype('O'),
#  'product_group': dtype('O'),
#  'product_group_company_shift_1': dtype('O'),
#  'product_group_company_shift_2': dtype('O'),
#  'product_group_company_shift_3': dtype('O'),
#  'product_group_km_shift_1': dtype('O'),
#  'product_group_km_shift_2': dtype('O'),
#  'product_group_km_shift_3': dtype('O'),
#  'products_lizing': dtype('float64'),
#  'products_lizing_ratio': dtype('float64'),
#  'products_lizing_ratio_share_prod_shift_2': dtype('float64'),
#  'products_lizing_ratio_share_prod_shift_3': dtype('float64'),
#  'products_lizing_share_prod_shift_2': dtype('float64'),
#  'products_lizing_share_prod_shift_3': dtype('float64'),
#  'proekt_finans': dtype('float64'),
#  'proekt_finans_ratio': dtype('float64'),
#  'proekt_finans_ratio_share_prod_shift_2': dtype('float64'),
#  'proekt_finans_ratio_share_prod_shift_3': dtype('float64'),
#  'proekt_finans_share_prod_shift_2': dtype('float64'),
#  'proekt_finans_share_prod_shift_3': dtype('float64'),
#  'samoinkass': dtype('float64'),
#  'samoinkass_ratio': dtype('float64'),
#  'samoinkass_ratio_share_prod_shift_2': dtype('float64'),
#  'samoinkass_ratio_share_prod_shift_3': dtype('float64'),
#  'samoinkass_share_prod_shift_2': dtype('float64'),
#  'samoinkass_share_prod_shift_3': dtype('float64'),
#  'segment_client': dtype('O'),
#  'spec_acc': dtype('float64'),
#  'spec_acc_ratio': dtype('float64'),
#  'spec_acc_ratio_share_prod_shift_2': dtype('float64'),
#  'spec_acc_ratio_share_prod_shift_3': dtype('float64'),
#  'spec_acc_share_prod_shift_2': dtype('float64'),
#  'spec_acc_share_prod_shift_3': dtype('float64'),
#  'sum_refused': dtype('float64'),
#  'sum_refused_agg_company_shift_1': dtype('float64'),
#  'sum_refused_agg_company_shift_2': dtype('float64'),
#  'sum_refused_agg_company_shift_3': dtype('float64'),
#  'sum_refused_agg_km_shift_1': dtype('float64'),
#  'sum_refused_agg_km_shift_2': dtype('float64'),
#  'sum_refused_agg_km_shift_3': dtype('float64'),
#  'sum_refused_company_shift_1': dtype('float64'),
#  'sum_refused_company_shift_2': dtype('float64'),
#  'sum_refused_company_shift_3': dtype('float64'),
#  'sum_refused_cumulate': dtype('float64'),
#  'sum_refused_cumulate_agg_company_shift_1': dtype('float64'),
#  'sum_refused_cumulate_agg_company_shift_2': dtype('float64'),
#  'sum_refused_cumulate_agg_company_shift_3': dtype('float64'),
#  'sum_refused_cumulate_agg_km_shift_1': dtype('float64'),
#  'sum_refused_cumulate_agg_km_shift_2': dtype('float64'),
#  'sum_refused_cumulate_agg_km_shift_3': dtype('float64'),
#  'sum_refused_cumulate_company_shift_1': dtype('float64'),
#  'sum_refused_cumulate_company_shift_2': dtype('float64'),
#  'sum_refused_cumulate_company_shift_3': dtype('float64'),
#  'sum_refused_cumulate_km_shift_2': dtype('float64'),
#  'sum_refused_cumulate_km_shift_3': dtype('float64'),
#  'sum_refused_km_shift_2': dtype('float64'),
#  'sum_refused_km_shift_3': dtype('float64'),
#  'sum_refused_tota_cumulate': dtype('float64'),
#  'sum_refused_tota_cumulate_agg_km_shift_1': dtype('float64'),
#  'sum_refused_tota_cumulate_agg_km_shift_2': dtype('float64'),
#  'sum_refused_tota_cumulate_agg_km_shift_3': dtype('float64'),
#  'sum_refused_tota_cumulate_km_shift_2': dtype('float64'),
#  'sum_refused_tota_cumulate_km_shift_3': dtype('float64'),
#  'sum_refused_total': dtype('float64'),
#  'sum_refused_total_agg_company_shift_1': dtype('float64'),
#  'sum_refused_total_agg_company_shift_2': dtype('float64'),
#  'sum_refused_total_agg_company_shift_3': dtype('float64'),
#  'sum_refused_total_agg_km_shift_1': dtype('float64'),
#  'sum_refused_total_agg_km_shift_2': dtype('float64'),
#  'sum_refused_total_agg_km_shift_3': dtype('float64'),
#  'sum_refused_total_company_shift_1': dtype('float64'),
#  'sum_refused_total_company_shift_2': dtype('float64'),
#  'sum_refused_total_company_shift_3': dtype('float64'),
#  'sum_refused_total_cumulate': dtype('float64'),
#  'sum_refused_total_cumulate_agg_company_shift_1': dtype('float64'),
#  'sum_refused_total_cumulate_agg_company_shift_2': dtype('float64'),
#  'sum_refused_total_cumulate_agg_company_shift_3': dtype('float64'),
#  'sum_refused_total_cumulate_company_shift_2': dtype('float64'),
#  'sum_refused_total_cumulate_company_shift_3': dtype('float64'),
#  'sum_refused_total_km_shift_2': dtype('float64'),
#  'sum_refused_total_km_shift_3': dtype('float64'),
#  'sum_sold': dtype('float64'),
#  'sum_sold_agg_company_shift_1': dtype('float64'),
#  'sum_sold_agg_company_shift_2': dtype('float64'),
#  'sum_sold_agg_company_shift_3': dtype('float64'),
#  'sum_sold_agg_km_shift_1': dtype('float64'),
#  'sum_sold_agg_km_shift_2': dtype('float64'),
#  'sum_sold_agg_km_shift_3': dtype('float64'),
#  'sum_sold_company_shift_1': dtype('float64'),
#  'sum_sold_company_shift_2': dtype('float64'),
#  'sum_sold_company_shift_3': dtype('float64'),
#  'sum_sold_cumulate': dtype('float64'),
#  'sum_sold_cumulate_agg_company_shift_1': dtype('float64'),
#  'sum_sold_cumulate_agg_company_shift_2': dtype('float64'),
#  'sum_sold_cumulate_agg_company_shift_3': dtype('float64'),
#  'sum_sold_cumulate_agg_km_shift_1': dtype('float64'),
#  'sum_sold_cumulate_agg_km_shift_2': dtype('float64'),
#  'sum_sold_cumulate_agg_km_shift_3': dtype('float64'),
#  'sum_sold_cumulate_company_shift_1': dtype('float64'),
#  'sum_sold_cumulate_company_shift_2': dtype('float64'),
#  'sum_sold_cumulate_company_shift_3': dtype('float64'),
#  'sum_sold_cumulate_km_shift_2': dtype('float64'),
#  'sum_sold_cumulate_km_shift_3': dtype('float64'),
#  'sum_sold_km_shift_2': dtype('float64'),
#  'sum_sold_km_shift_3': dtype('float64'),
#  'sum_sold_total': dtype('float64'),
#  'sum_sold_total_agg_company_shift_1': dtype('float64'),
#  'sum_sold_total_agg_company_shift_2': dtype('float64'),
#  'sum_sold_total_agg_company_shift_3': dtype('float64'),
#  'sum_sold_total_agg_km_shift_1': dtype('float64'),
#  'sum_sold_total_agg_km_shift_2': dtype('float64'),
#  'sum_sold_total_agg_km_shift_3': dtype('float64'),
#  'sum_sold_total_company_shift_1': dtype('float64'),
#  'sum_sold_total_company_shift_2': dtype('float64'),
#  'sum_sold_total_company_shift_3': dtype('float64'),
#  'sum_sold_total_cumulate': dtype('float64'),
#  'sum_sold_total_cumulate_agg_company_shift_1': dtype('float64'),
#  'sum_sold_total_cumulate_agg_company_shift_2': dtype('float64'),
#  'sum_sold_total_cumulate_agg_company_shift_3': dtype('float64'),
#  'sum_sold_total_cumulate_agg_km_shift_1': dtype('float64'),
#  'sum_sold_total_cumulate_agg_km_shift_2': dtype('float64'),
#  'sum_sold_total_cumulate_agg_km_shift_3': dtype('float64'),
#  'sum_sold_total_cumulate_company_shift_1': dtype('float64'),
#  'sum_sold_total_cumulate_company_shift_2': dtype('float64'),
#  'sum_sold_total_cumulate_company_shift_3': dtype('float64'),
#  'sum_sold_total_cumulate_km_shift_2': dtype('float64'),
#  'sum_sold_total_cumulate_km_shift_3': dtype('float64'),
#  'sum_sold_total_km_shift_2': dtype('float64'),
#  'sum_sold_total_km_shift_3': dtype('float64'),
#  'tb': dtype('O'),
#  'total_client_cnt': dtype('float64'),
#  'total_client_cnt_share_prod_shift_2': dtype('float64'),
#  'total_client_cnt_share_prod_shift_3': dtype('float64'),
#  'type_object': dtype('O'),
#  'valuta_control': dtype('float64'),
#  'valuta_control_ratio': dtype('float64'),
#  'valuta_control_ratio_share_prod_shift_2': dtype('float64'),
#  'valuta_control_ratio_share_prod_shift_3': dtype('float64'),
#  'valuta_control_share_prod_shift_2': dtype('float64'),
#  'valuta_control_share_prod_shift_3': dtype('float64'),
#  'veksel': dtype('float64'),
#  'veksel_ratio': dtype('float64'),
#  'veksel_ratio_share_prod_shift_2': dtype('float64'),
#  'veksel_ratio_share_prod_shift_3': dtype('float64'),
#  'veksel_share_prod_shift_2': dtype('float64'),
#  'veksel_share_prod_shift_3': dtype('float64'),
#  'vko_id': dtype('O'),
#  'work_sreda': dtype('float64'),
#  'work_sreda_ratio': dtype('float64'),
#  'work_sreda_ratio_share_prod_shift_2': dtype('float64'),
#  'work_sreda_ratio_share_prod_shift_3': dtype('float64'),
#  'work_sreda_share_prod_shift_2': dtype('float64'),
#  'work_sreda_share_prod_shift_3': dtype('float64'),
#  'year_n': dtype('int64'),
#  'zarplat_projects': dtype('float64'),
#  'zarplat_projects_ratio': dtype('float64'),
#  'zarplat_projects_ratio_share_prod_shift_2': dtype('float64'),
#  'zarplat_projects_ratio_share_prod_shift_3': dtype('float64'),
#  'zarplat_projects_share_prod_shift_2': dtype('float64'),
#  'zarplat_projects_share_prod_shift_3': dtype('float64')}

# %%
df=df.T.drop_duplicates().T

# %%
for col in df.columns:
    if col in list(coltypes.keys()):
        df[col]=df[col].astype(coltypes[col], copy=False)

# %%
df.sort_values('date_create', ascending=True, inplace=True)

# %%
import re
colsdel = (c for c in df.columns if re.search('(product_group_|month__)[km_shift_\d+|company_shift_\d+]', c.lower()))
colsdel=list(colsdel)
colsdel
# Out:
# ['product_group_km_shift_1',
#  'month__company_shift_1',
#  'product_group_company_shift_1',
#  'month__km_shift_2',
#  'product_group_km_shift_2',
#  'month__company_shift_2',
#  'product_group_company_shift_2',
#  'month__km_shift_3',
#  'product_group_km_shift_3',
#  'month__company_shift_3',
#  'product_group_company_shift_3',
#  'month__agg_km_shift_1',
#  'month__agg_company_shift_1',
#  'month__agg_km_shift_2',
#  'month__agg_company_shift_2',
#  'month__agg_km_shift_3',
#  'month__agg_company_shift_3',
#  'month__share_prod_shift_1',
#  'month__share_prod_shift_2',
#  'month__share_prod_shift_3']

# %%
cols_for_drop = ['id', 'vko_id', 'company_id', 'inn', 'ckp_id', 'year_n', 'month_n', 
                 'date_create', 'date_close',
                 'kp_prev_1', 'kp_prev_2','kp_prev_3', 'month_','ckp', 'type_object']
cols_for_drop.extend(colsdel)
cols_for_drop
# Out:
# ['id',
#  'vko_id',
#  'company_id',
#  'inn',
#  'ckp_id',
#  'year_n',
#  'month_n',
#  'date_create',
#  'date_close',
#  'kp_prev_1',
#  'kp_prev_2',
#  'kp_prev_3',
#  'month_',
#  'ckp',
#  'type_object',
#  'product_group_km_shift_1',
#  'month__company_shift_1',
#  'product_group_company_shift_1',
#  'month__km_shift_2',
#  'product_group_km_shift_2',
#  'month__company_shift_2',
#  'product_group_company_shift_2',
#  'month__km_shift_3',
#  'product_group_km_shift_3',
#  'month__company_shift_3',
#  'product_group_company_shift_3',
#  'month__agg_km_shift_1',
#  'month__agg_company_shift_1',
#  'month__agg_km_shift_2',
#  'month__agg_company_shift_2',
#  'month__agg_km_shift_3',
#  'month__agg_company_shift_3',
#  'month__share_prod_shift_1',
#  'month__share_prod_shift_2',
#  'month__share_prod_shift_3']

# %% [markdown]
# list(set(df['product_group']) - set(df['product_group_km_shift_3']))

# %% [markdown]
# df['is_previous_sold'].isnull().sum()-df['is_previous_sold_km_dealdiff'].isnull().sum()

# %% [markdown]
# d=abs(df['is_previous_sold']-df['is_previous_sold_km_dealdiff'])
# d=d.fillna(-1)
# d[d==0].count()

# %% [markdown]
# d=abs(df['days_between']-df['days_between_km_dealdiff'])
# d=d.fillna(-1)
# d[d>=1].count()

# %%
df = df.drop(cols_for_drop, axis=1, errors='ignore')

# %%
df.head()
# Out:
#                        tb                  gosb             product  \
# 0         Московский банк       Московский банк         E-invoicing
# 1      Среднерусский банк   Западное ГОСБ №1025         E-invoicing
# 2  Западно-Сибирский банк  Тюменское ГОСБ №0029         E-invoicing
# 3      Среднерусский банк  Рязанское ГОСБ №8606  Депозиты (срочные)
# 4  Западно-Сибирский банк  Тюменское ГОСБ №0029      Страхование НС
#
#                   product_group  days_cr_q_end segment_client priority_client  \
# 0    ДИСТАНЦИОННОЕ ОБСЛУЖИВАНИЕ             88          Малые             Нет
# 1    ДИСТАНЦИОННОЕ ОБСЛУЖИВАНИЕ             75          Микро             Нет
# 2    ДИСТАНЦИОННОЕ ОБСЛУЖИВАНИЕ             75          Микро             Нет
# 3  ПРОДУКТЫ ПРИВЛЕЧЕНИЯ СРЕДСТВ             60          Малые             Нет
# 4                   СТРАХОВАНИЕ             57          Микро        Ключевой
#
#    sum_sold  sum_sold_cumulate  sum_refused  sum_refused_cumulate  \
# 0       NaN                NaN          NaN                   NaN
# 1       NaN                NaN          NaN                   NaN
# 2       NaN                NaN          NaN                   NaN
# 3       NaN                NaN          NaN                   NaN
# 4       NaN                NaN          NaN                   NaN
#
#    sum_sold_total  sum_sold_total_cumulate  sum_refused_total  \
# 0             NaN                      NaN                NaN
# 1             NaN                      NaN                NaN
# 2             NaN                      NaN                NaN
# 3             NaN                      NaN                NaN
# 4             NaN                      NaN                NaN
#
#    sum_refused_tota_cumulate  sum_sold_company_shift_1  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#    sum_sold_cumulate_company_shift_1  sum_refused_company_shift_1  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#    sum_refused_cumulate_company_shift_1  sum_sold_total_company_shift_1  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
#
#    sum_sold_total_cumulate_company_shift_1  sum_refused_total_company_shift_1  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
#
#    sum_refused_total_cumulate  sum_sold_km_shift_2  \
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN
#
#    sum_sold_cumulate_km_shift_2  sum_refused_km_shift_2  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#    sum_refused_cumulate_km_shift_2  sum_sold_total_km_shift_2  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
#
#    sum_sold_total_cumulate_km_shift_2  sum_refused_total_km_shift_2  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
#
#    sum_refused_tota_cumulate_km_shift_2  sum_sold_company_shift_2  \
# 0                                   NaN                       NaN
# 1                                   NaN                       NaN
# 2                                   NaN                       NaN
# 3                                   NaN                       NaN
# 4                                   NaN                       NaN
#
#    sum_sold_cumulate_company_shift_2  sum_refused_company_shift_2  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#    sum_refused_cumulate_company_shift_2  sum_sold_total_company_shift_2  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
#
#    sum_sold_total_cumulate_company_shift_2  sum_refused_total_company_shift_2  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
#
#    sum_refused_total_cumulate_company_shift_2  sum_sold_km_shift_3  \
# 0                                         NaN                  NaN
# 1                                         NaN                  NaN
# 2                                         NaN                  NaN
# 3                                         NaN                  NaN
# 4                                         NaN                  NaN
#
#    sum_sold_cumulate_km_shift_3  sum_refused_km_shift_3  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#    sum_refused_cumulate_km_shift_3  sum_sold_total_km_shift_3  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
#
#    sum_sold_total_cumulate_km_shift_3  sum_refused_total_km_shift_3  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
#
#    sum_refused_tota_cumulate_km_shift_3  sum_sold_company_shift_3  \
# 0                                   NaN                       NaN
# 1                                   NaN                       NaN
# 2                                   NaN                       NaN
# 3                                   NaN                       NaN
# 4                                   NaN                       NaN
#
#    sum_sold_cumulate_company_shift_3  sum_refused_company_shift_3  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#    sum_refused_cumulate_company_shift_3  sum_sold_total_company_shift_3  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
#
#    sum_sold_total_cumulate_company_shift_3  sum_refused_total_company_shift_3  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
#
#    sum_refused_total_cumulate_company_shift_3  sum_sold_agg_km_shift_1  \
# 0                                         NaN                      NaN
# 1                                         NaN                      NaN
# 2                                         NaN                      NaN
# 3                                         NaN                      NaN
# 4                                         NaN                      NaN
#
#    sum_sold_cumulate_agg_km_shift_1  sum_refused_agg_km_shift_1  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
#
#    sum_refused_cumulate_agg_km_shift_1  sum_sold_total_agg_km_shift_1  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#    sum_sold_total_cumulate_agg_km_shift_1  sum_refused_total_agg_km_shift_1  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#    sum_refused_tota_cumulate_agg_km_shift_1  sum_sold_agg_company_shift_1  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
#
#    sum_sold_cumulate_agg_company_shift_1  sum_refused_agg_company_shift_1  \
# 0                                    NaN                              NaN
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
#
#    sum_refused_cumulate_agg_company_shift_1  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    sum_sold_total_agg_company_shift_1  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    sum_sold_total_cumulate_agg_company_shift_1  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    sum_refused_total_agg_company_shift_1  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    sum_refused_total_cumulate_agg_company_shift_1  sum_sold_agg_km_shift_2  \
# 0                                             NaN                      NaN
# 1                                             NaN                      NaN
# 2                                             NaN                      NaN
# 3                                             NaN                      NaN
# 4                                             NaN                      NaN
#
#    sum_sold_cumulate_agg_km_shift_2  sum_refused_agg_km_shift_2  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
#
#    sum_refused_cumulate_agg_km_shift_2  sum_sold_total_agg_km_shift_2  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#    sum_sold_total_cumulate_agg_km_shift_2  sum_refused_total_agg_km_shift_2  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#    sum_refused_tota_cumulate_agg_km_shift_2  sum_sold_agg_company_shift_2  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
#
#    sum_sold_cumulate_agg_company_shift_2  sum_refused_agg_company_shift_2  \
# 0                                    NaN                              NaN
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
#
#    sum_refused_cumulate_agg_company_shift_2  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    sum_sold_total_agg_company_shift_2  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    sum_sold_total_cumulate_agg_company_shift_2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    sum_refused_total_agg_company_shift_2  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    sum_refused_total_cumulate_agg_company_shift_2  sum_sold_agg_km_shift_3  \
# 0                                             NaN                      NaN
# 1                                             NaN                      NaN
# 2                                             NaN                      NaN
# 3                                             NaN                      NaN
# 4                                             NaN                      NaN
#
#    sum_sold_cumulate_agg_km_shift_3  sum_refused_agg_km_shift_3  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
#
#    sum_refused_cumulate_agg_km_shift_3  sum_sold_total_agg_km_shift_3  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#    sum_sold_total_cumulate_agg_km_shift_3  sum_refused_total_agg_km_shift_3  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#    sum_refused_tota_cumulate_agg_km_shift_3  sum_sold_agg_company_shift_3  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
#
#    sum_sold_cumulate_agg_company_shift_3  sum_refused_agg_company_shift_3  \
# 0                                    NaN                              NaN
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
#
#    sum_refused_cumulate_agg_company_shift_3  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    sum_sold_total_agg_company_shift_3  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    sum_sold_total_cumulate_agg_company_shift_3  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    sum_refused_total_agg_company_shift_3  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    sum_refused_total_cumulate_agg_company_shift_3  total_client_cnt  \
# 0                                             NaN               NaN
# 1                                             NaN               NaN
# 2                                             NaN               NaN
# 3                                             NaN               NaN
# 4                                             NaN               NaN
#
#    oborot_kredit  invest_kredit  overdraft_kredit  proekt_finans  \
# 0            NaN            NaN               NaN            NaN
# 1            NaN            NaN               NaN            NaN
# 2            NaN            NaN               NaN            NaN
# 3            NaN            NaN               NaN            NaN
# 4            NaN            NaN               NaN            NaN
#
#    products_lizing  obsluzh_rts_rur  obsluzh_rts_val  spec_acc  deposit  \
# 0              NaN              NaN              NaN       NaN      NaN
# 1              NaN              NaN              NaN       NaN      NaN
# 2              NaN              NaN              NaN       NaN      NaN
# 3              NaN              NaN              NaN       NaN      NaN
# 4              NaN              NaN              NaN       NaN      NaN
#
#    veksel  deposit_sertificat  inkass  samoinkass  zarplat_projects  \
# 0     NaN                 NaN     NaN         NaN               NaN
# 1     NaN                 NaN     NaN         NaN               NaN
# 2     NaN                 NaN     NaN         NaN               NaN
# 3     NaN                 NaN     NaN         NaN               NaN
# 4     NaN                 NaN     NaN         NaN               NaN
#
#    acquiring_torg  acquiring_mobile  acreditiv  valuta_control  \
# 0             NaN               NaN        NaN             NaN
# 1             NaN               NaN        NaN             NaN
# 2             NaN               NaN        NaN             NaN
# 3             NaN               NaN        NaN             NaN
# 4             NaN               NaN        NaN             NaN
#
#    garantee_kontract  garantee_gos  garantee_other  arenda_seyf  dbo  \
# 0                NaN           NaN             NaN          NaN  NaN
# 1                NaN           NaN             NaN          NaN  NaN
# 2                NaN           NaN             NaN          NaN  NaN
# 3                NaN           NaN             NaN          NaN  NaN
# 4                NaN           NaN             NaN          NaN  NaN
#
#    corporate_cards  cash_management  bank_straxovanie_imush  \
# 0              NaN              NaN                     NaN
# 1              NaN              NaN                     NaN
# 2              NaN              NaN                     NaN
# 3              NaN              NaN                     NaN
# 4              NaN              NaN                     NaN
#
#    bank_straxovanie_lich  bank_straxovanie_otvet  einvoicing  factoring  \
# 0                    NaN                     NaN         NaN        NaN
# 1                    NaN                     NaN         NaN        NaN
# 2                    NaN                     NaN         NaN        NaN
# 3                    NaN                     NaN         NaN        NaN
# 4                    NaN                     NaN         NaN        NaN
#
#    konversion  ns_servis  ns_terminal  work_sreda  ns_sait  ns_garant  pfi  \
# 0         NaN        NaN          NaN         NaN      NaN        NaN  NaN
# 1         NaN        NaN          NaN         NaN      NaN        NaN  NaN
# 2         NaN        NaN          NaN         NaN      NaN        NaN  NaN
# 3         NaN        NaN          NaN         NaN      NaN        NaN  NaN
# 4         NaN        NaN          NaN         NaN      NaN        NaN  NaN
#
#    dcd  inkass_ratio  bank_straxovanie_imush_ratio  einvoicing_ratio  \
# 0  NaN           NaN                           NaN               NaN
# 1  NaN           NaN                           NaN               NaN
# 2  NaN           NaN                           NaN               NaN
# 3  NaN           NaN                           NaN               NaN
# 4  NaN           NaN                           NaN               NaN
#
#    deposit_sertificat_ratio  acquiring_torg_ratio  konversion_ratio  \
# 0                       NaN                   NaN               NaN
# 1                       NaN                   NaN               NaN
# 2                       NaN                   NaN               NaN
# 3                       NaN                   NaN               NaN
# 4                       NaN                   NaN               NaN
#
#    overdraft_kredit_ratio  work_sreda_ratio  samoinkass_ratio  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
#    factoring_ratio  garantee_gos_ratio  obsluzh_rts_val_ratio  \
# 0              NaN                 NaN                    NaN
# 1              NaN                 NaN                    NaN
# 2              NaN                 NaN                    NaN
# 3              NaN                 NaN                    NaN
# 4              NaN                 NaN                    NaN
#
#    invest_kredit_ratio  corporate_cards_ratio  acreditiv_ratio  deposit_ratio  \
# 0                  NaN                    NaN              NaN            NaN
# 1                  NaN                    NaN              NaN            NaN
# 2                  NaN                    NaN              NaN            NaN
# 3                  NaN                    NaN              NaN            NaN
# 4                  NaN                    NaN              NaN            NaN
#
#    oborot_kredit_ratio  cash_management_ratio  ns_terminal_ratio  \
# 0                  NaN                    NaN                NaN
# 1                  NaN                    NaN                NaN
# 2                  NaN                    NaN                NaN
# 3                  NaN                    NaN                NaN
# 4                  NaN                    NaN                NaN
#
#    ns_garant_ratio  spec_acc_ratio  products_lizing_ratio  dbo_ratio  \
# 0              NaN             NaN                    NaN        NaN
# 1              NaN             NaN                    NaN        NaN
# 2              NaN             NaN                    NaN        NaN
# 3              NaN             NaN                    NaN        NaN
# 4              NaN             NaN                    NaN        NaN
#
#    bank_straxovanie_lich_ratio  veksel_ratio  dcd_ratio  \
# 0                          NaN           NaN        NaN
# 1                          NaN           NaN        NaN
# 2                          NaN           NaN        NaN
# 3                          NaN           NaN        NaN
# 4                          NaN           NaN        NaN
#
#    acquiring_mobile_ratio  bank_straxovanie_otvet_ratio  garantee_other_ratio  \
# 0                     NaN                           NaN                   NaN
# 1                     NaN                           NaN                   NaN
# 2                     NaN                           NaN                   NaN
# 3                     NaN                           NaN                   NaN
# 4                     NaN                           NaN                   NaN
#
#    pfi_ratio  proekt_finans_ratio  arenda_seyf_ratio  valuta_control_ratio  \
# 0        NaN                  NaN                NaN                   NaN
# 1        NaN                  NaN                NaN                   NaN
# 2        NaN                  NaN                NaN                   NaN
# 3        NaN                  NaN                NaN                   NaN
# 4        NaN                  NaN                NaN                   NaN
#
#    zarplat_projects_ratio  garantee_kontract_ratio  ns_servis_ratio  \
# 0                     NaN                      NaN              NaN
# 1                     NaN                      NaN              NaN
# 2                     NaN                      NaN              NaN
# 3                     NaN                      NaN              NaN
# 4                     NaN                      NaN              NaN
#
#    ns_sait_ratio  obsluzh_rts_rur_ratio  total_client_cnt_share_prod_shift_2  \
# 0            NaN                    NaN                                  NaN
# 1            NaN                    NaN                                  NaN
# 2            NaN                    NaN                                  NaN
# 3            NaN                    NaN                                  NaN
# 4            NaN                    NaN                                  NaN
#
#    oborot_kredit_share_prod_shift_2  invest_kredit_share_prod_shift_2  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    overdraft_kredit_share_prod_shift_2  proekt_finans_share_prod_shift_2  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
#
#    products_lizing_share_prod_shift_2  obsluzh_rts_rur_share_prod_shift_2  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    obsluzh_rts_val_share_prod_shift_2  spec_acc_share_prod_shift_2  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
#
#    deposit_share_prod_shift_2  veksel_share_prod_shift_2  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    deposit_sertificat_share_prod_shift_2  inkass_share_prod_shift_2  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                                    NaN                        NaN
# 4                                    NaN                        NaN
#
#    samoinkass_share_prod_shift_2  zarplat_projects_share_prod_shift_2  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    acquiring_torg_share_prod_shift_2  acquiring_mobile_share_prod_shift_2  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    acreditiv_share_prod_shift_2  valuta_control_share_prod_shift_2  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4                           NaN                                NaN
#
#    garantee_kontract_share_prod_shift_2  garantee_gos_share_prod_shift_2  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
#
#    garantee_other_share_prod_shift_2  arenda_seyf_share_prod_shift_2  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#    dbo_share_prod_shift_2  corporate_cards_share_prod_shift_2  \
# 0                     NaN                                 NaN
# 1                     NaN                                 NaN
# 2                     NaN                                 NaN
# 3                     NaN                                 NaN
# 4                     NaN                                 NaN
#
#    cash_management_share_prod_shift_2  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    bank_straxovanie_imush_share_prod_shift_2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    bank_straxovanie_lich_share_prod_shift_2  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    bank_straxovanie_otvet_share_prod_shift_2  einvoicing_share_prod_shift_2  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
#
#    factoring_share_prod_shift_2  konversion_share_prod_shift_2  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#    ns_servis_share_prod_shift_2  ns_terminal_share_prod_shift_2  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    work_sreda_share_prod_shift_2  ns_sait_share_prod_shift_2  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#    ns_garant_share_prod_shift_2  pfi_share_prod_shift_2  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#    dcd_share_prod_shift_2  inkass_ratio_share_prod_shift_2  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
#
#    bank_straxovanie_imush_ratio_share_prod_shift_2  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    einvoicing_ratio_share_prod_shift_2  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    deposit_sertificat_ratio_share_prod_shift_2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    acquiring_torg_ratio_share_prod_shift_2  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    konversion_ratio_share_prod_shift_2  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    overdraft_kredit_ratio_share_prod_shift_2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    work_sreda_ratio_share_prod_shift_2  samoinkass_ratio_share_prod_shift_2  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    factoring_ratio_share_prod_shift_2  garantee_gos_ratio_share_prod_shift_2  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                                 NaN                                    NaN
# 3                                 NaN                                    NaN
# 4                                 NaN                                    NaN
#
#    obsluzh_rts_val_ratio_share_prod_shift_2  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    invest_kredit_ratio_share_prod_shift_2  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    corporate_cards_ratio_share_prod_shift_2  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    acreditiv_ratio_share_prod_shift_2  deposit_ratio_share_prod_shift_2  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
#
#    oborot_kredit_ratio_share_prod_shift_2  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    cash_management_ratio_share_prod_shift_2  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    ns_terminal_ratio_share_prod_shift_2  ns_garant_ratio_share_prod_shift_2  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#    spec_acc_ratio_share_prod_shift_2  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    products_lizing_ratio_share_prod_shift_2  dbo_ratio_share_prod_shift_2  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
#
#    bank_straxovanie_lich_ratio_share_prod_shift_2  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    veksel_ratio_share_prod_shift_2  dcd_ratio_share_prod_shift_2  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
#
#    acquiring_mobile_ratio_share_prod_shift_2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    bank_straxovanie_otvet_ratio_share_prod_shift_2  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    garantee_other_ratio_share_prod_shift_2  pfi_ratio_share_prod_shift_2  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
#
#    proekt_finans_ratio_share_prod_shift_2  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    arenda_seyf_ratio_share_prod_shift_2  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    valuta_control_ratio_share_prod_shift_2  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    zarplat_projects_ratio_share_prod_shift_2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    garantee_kontract_ratio_share_prod_shift_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    ns_servis_ratio_share_prod_shift_2  ns_sait_ratio_share_prod_shift_2  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# ...
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    zarplat_projects_share_prod_shift_3  acquiring_torg_share_prod_shift_3  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    acquiring_mobile_share_prod_shift_3  acreditiv_share_prod_shift_3  \
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
#
#    valuta_control_share_prod_shift_3  garantee_kontract_share_prod_shift_3  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
# 2                                NaN                                   NaN
# 3                                NaN                                   NaN
# 4                                NaN                                   NaN
#
#    garantee_gos_share_prod_shift_3  garantee_other_share_prod_shift_3  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#    arenda_seyf_share_prod_shift_3  dbo_share_prod_shift_3  \
# 0                             NaN                     NaN
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3                             NaN                     NaN
# 4                             NaN                     NaN
#
#    corporate_cards_share_prod_shift_3  cash_management_share_prod_shift_3  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    bank_straxovanie_imush_share_prod_shift_3  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    bank_straxovanie_lich_share_prod_shift_3  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    bank_straxovanie_otvet_share_prod_shift_3  einvoicing_share_prod_shift_3  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
#
#    factoring_share_prod_shift_3  konversion_share_prod_shift_3  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#    ns_servis_share_prod_shift_3  ns_terminal_share_prod_shift_3  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    work_sreda_share_prod_shift_3  ns_sait_share_prod_shift_3  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#    ns_garant_share_prod_shift_3  pfi_share_prod_shift_3  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#    dcd_share_prod_shift_3  inkass_ratio_share_prod_shift_3  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
#
#    bank_straxovanie_imush_ratio_share_prod_shift_3  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    einvoicing_ratio_share_prod_shift_3  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    deposit_sertificat_ratio_share_prod_shift_3  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    acquiring_torg_ratio_share_prod_shift_3  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    konversion_ratio_share_prod_shift_3  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    overdraft_kredit_ratio_share_prod_shift_3  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    work_sreda_ratio_share_prod_shift_3  samoinkass_ratio_share_prod_shift_3  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    factoring_ratio_share_prod_shift_3  garantee_gos_ratio_share_prod_shift_3  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                                 NaN                                    NaN
# 3                                 NaN                                    NaN
# 4                                 NaN                                    NaN
#
#    obsluzh_rts_val_ratio_share_prod_shift_3  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    invest_kredit_ratio_share_prod_shift_3  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    corporate_cards_ratio_share_prod_shift_3  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    acreditiv_ratio_share_prod_shift_3  deposit_ratio_share_prod_shift_3  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
#
#    oborot_kredit_ratio_share_prod_shift_3  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    cash_management_ratio_share_prod_shift_3  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    ns_terminal_ratio_share_prod_shift_3  ns_garant_ratio_share_prod_shift_3  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#    spec_acc_ratio_share_prod_shift_3  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    products_lizing_ratio_share_prod_shift_3  dbo_ratio_share_prod_shift_3  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
#
#    bank_straxovanie_lich_ratio_share_prod_shift_3  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    veksel_ratio_share_prod_shift_3  dcd_ratio_share_prod_shift_3  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
#
#    acquiring_mobile_ratio_share_prod_shift_3  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    bank_straxovanie_otvet_ratio_share_prod_shift_3  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    garantee_other_ratio_share_prod_shift_3  pfi_ratio_share_prod_shift_3  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
#
#    proekt_finans_ratio_share_prod_shift_3  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    arenda_seyf_ratio_share_prod_shift_3  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    valuta_control_ratio_share_prod_shift_3  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    zarplat_projects_ratio_share_prod_shift_3  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    garantee_kontract_ratio_share_prod_shift_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    ns_servis_ratio_share_prod_shift_3  ns_sait_ratio_share_prod_shift_3  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
#
#    obsluzh_rts_rur_ratio_share_prod_shift_3  days_between  is_previous_sold  \
# 0                                       NaN           NaN               NaN
# 1                                       NaN           NaN               NaN
# 2                                       NaN           NaN               NaN
# 3                                       NaN           NaN               NaN
# 4                                       NaN           NaN               NaN
#
#    days_between_km_dealdiff  is_previous_sold_km_dealdiff
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN

# %%
null_compare = pd.DataFrame(df.isnull().sum(), columns=['train_null_count'])
null_compare['train_null_ratio'] = null_compare['train_null_count'] / df.shape[0] * 100
null_compare
# Out:
#                                                  train_null_count  \
# tb                                                              1
# gosb                                                            4
# product                                                         0
# product_group                                                   0
# days_cr_q_end                                                   0
# segment_client                                                  0
# priority_client                                                 0
# sum_sold                                                     3220
# sum_sold_cumulate                                            3220
# sum_refused                                                  3220
# sum_refused_cumulate                                         3220
# sum_sold_total                                               3220
# sum_sold_total_cumulate                                      3220
# sum_refused_total                                            3220
# sum_refused_tota_cumulate                                    3220
# sum_sold_company_shift_1                                    18325
# sum_sold_cumulate_company_shift_1                           18325
# sum_refused_company_shift_1                                 18325
# sum_refused_cumulate_company_shift_1                        18325
# sum_sold_total_company_shift_1                              18325
# sum_sold_total_cumulate_company_shift_1                     18325
# sum_refused_total_company_shift_1                           18325
# sum_refused_total_cumulate                                  18325
# sum_sold_km_shift_2                                          3244
# sum_sold_cumulate_km_shift_2                                 3244
# sum_refused_km_shift_2                                       3244
# sum_refused_cumulate_km_shift_2                              3244
# sum_sold_total_km_shift_2                                    3244
# sum_sold_total_cumulate_km_shift_2                           3244
# sum_refused_total_km_shift_2                                 3244
# sum_refused_tota_cumulate_km_shift_2                         3244
# sum_sold_company_shift_2                                    18331
# sum_sold_cumulate_company_shift_2                           18331
# sum_refused_company_shift_2                                 18331
# sum_refused_cumulate_company_shift_2                        18331
# sum_sold_total_company_shift_2                              18331
# sum_sold_total_cumulate_company_shift_2                     18331
# sum_refused_total_company_shift_2                           18331
# sum_refused_total_cumulate_company_shift_2                  18331
# sum_sold_km_shift_3                                          3267
# sum_sold_cumulate_km_shift_3                                 3267
# sum_refused_km_shift_3                                       3267
# sum_refused_cumulate_km_shift_3                              3267
# sum_sold_total_km_shift_3                                    3267
# sum_sold_total_cumulate_km_shift_3                           3267
# sum_refused_total_km_shift_3                                 3267
# sum_refused_tota_cumulate_km_shift_3                         3267
# sum_sold_company_shift_3                                    18335
# sum_sold_cumulate_company_shift_3                           18335
# sum_refused_company_shift_3                                 18335
# sum_refused_cumulate_company_shift_3                        18335
# sum_sold_total_company_shift_3                              18335
# sum_sold_total_cumulate_company_shift_3                     18335
# sum_refused_total_company_shift_3                           18335
# sum_refused_total_cumulate_company_shift_3                  18335
# sum_sold_agg_km_shift_1                                      1124
# sum_sold_cumulate_agg_km_shift_1                             1124
# sum_refused_agg_km_shift_1                                   1124
# sum_refused_cumulate_agg_km_shift_1                          1124
# sum_sold_total_agg_km_shift_1                                1124
# sum_sold_total_cumulate_agg_km_shift_1                       1124
# sum_refused_total_agg_km_shift_1                             1124
# sum_refused_tota_cumulate_agg_km_shift_1                     1124
# sum_sold_agg_company_shift_1                                17291
# sum_sold_cumulate_agg_company_shift_1                       17291
# sum_refused_agg_company_shift_1                             17291
# sum_refused_cumulate_agg_company_shift_1                    17291
# sum_sold_total_agg_company_shift_1                          17291
# sum_sold_total_cumulate_agg_company_shift_1                 17291
# sum_refused_total_agg_company_shift_1                       17291
# sum_refused_total_cumulate_agg_company_shift_1              17291
# sum_sold_agg_km_shift_2                                      1150
# sum_sold_cumulate_agg_km_shift_2                             1150
# sum_refused_agg_km_shift_2                                   1150
# sum_refused_cumulate_agg_km_shift_2                          1150
# sum_sold_total_agg_km_shift_2                                1150
# sum_sold_total_cumulate_agg_km_shift_2                       1150
# sum_refused_total_agg_km_shift_2                             1150
# sum_refused_tota_cumulate_agg_km_shift_2                     1150
# sum_sold_agg_company_shift_2                                17298
# sum_sold_cumulate_agg_company_shift_2                       17298
# sum_refused_agg_company_shift_2                             17298
# sum_refused_cumulate_agg_company_shift_2                    17298
# sum_sold_total_agg_company_shift_2                          17298
# sum_sold_total_cumulate_agg_company_shift_2                 17298
# sum_refused_total_agg_company_shift_2                       17298
# sum_refused_total_cumulate_agg_company_shift_2              17298
# sum_sold_agg_km_shift_3                                      1176
# sum_sold_cumulate_agg_km_shift_3                             1176
# sum_refused_agg_km_shift_3                                   1176
# sum_refused_cumulate_agg_km_shift_3                          1176
# sum_sold_total_agg_km_shift_3                                1176
# sum_sold_total_cumulate_agg_km_shift_3                       1176
# sum_refused_total_agg_km_shift_3                             1176
# sum_refused_tota_cumulate_agg_km_shift_3                     1176
# sum_sold_agg_company_shift_3                                17302
# sum_sold_cumulate_agg_company_shift_3                       17302
# sum_refused_agg_company_shift_3                             17302
# sum_refused_cumulate_agg_company_shift_3                    17302
# sum_sold_total_agg_company_shift_3                          17302
# sum_sold_total_cumulate_agg_company_shift_3                 17302
# sum_refused_total_agg_company_shift_3                       17302
# sum_refused_total_cumulate_agg_company_shift_3              17302
# total_client_cnt                                             1083
# oborot_kredit                                                1384
# invest_kredit                                                8571
# overdraft_kredit                                             3935
# proekt_finans                                               19695
# products_lizing                                              3329
# obsluzh_rts_rur                                              1158
# obsluzh_rts_val                                              3370
# spec_acc                                                     7828
# deposit                                                      1581
# veksel                                                      12965
# deposit_sertificat                                          19807
# inkass                                                       4841
# samoinkass                                                   1247
# zarplat_projects                                             1338
# acquiring_torg                                               1270
# acquiring_mobile                                             6630
# acreditiv                                                   17004
# valuta_control                                               1662
# garantee_kontract                                            7616
# garantee_gos                                                19841
# garantee_other                                              16257
# arenda_seyf                                                 18988
# dbo                                                          1101
# corporate_cards                                              1295
# cash_management                                              9149
# bank_straxovanie_imush                                       1619
# bank_straxovanie_lich                                        1741
# bank_straxovanie_otvet                                      18165
# einvoicing                                                   1415
# factoring                                                   19123
# konversion                                                   5164
# ns_servis                                                   16981
# ns_terminal                                                  5620
# work_sreda                                                  19832
# ns_sait                                                     14745
# ns_garant                                                   17942
# pfi                                                         19842
# dcd                                                         19757
# inkass_ratio                                                 4841
# bank_straxovanie_imush_ratio                                 1619
# einvoicing_ratio                                             1415
# deposit_sertificat_ratio                                    19807
# acquiring_torg_ratio                                         1270
# konversion_ratio                                             5164
# overdraft_kredit_ratio                                       3935
# work_sreda_ratio                                            19832
# samoinkass_ratio                                             1247
# factoring_ratio                                             19123
# garantee_gos_ratio                                          19841
# obsluzh_rts_val_ratio                                        3370
# invest_kredit_ratio                                          8571
# corporate_cards_ratio                                        1295
# acreditiv_ratio                                             17004
# deposit_ratio                                                1581
# oborot_kredit_ratio                                          1384
# cash_management_ratio                                        9149
# ns_terminal_ratio                                            5620
# ns_garant_ratio                                             17942
# spec_acc_ratio                                               7828
# products_lizing_ratio                                        3329
# dbo_ratio                                                    1101
# bank_straxovanie_lich_ratio                                  1741
# veksel_ratio                                                12965
# dcd_ratio                                                   19757
# acquiring_mobile_ratio                                       6630
# bank_straxovanie_otvet_ratio                                18165
# garantee_other_ratio                                        16257
# pfi_ratio                                                   19842
# proekt_finans_ratio                                         19695
# arenda_seyf_ratio                                           18988
# valuta_control_ratio                                         1662
# zarplat_projects_ratio                                       1338
# garantee_kontract_ratio                                      7616
# ns_servis_ratio                                             16981
# ns_sait_ratio                                               14745
# obsluzh_rts_rur_ratio                                        1158
# total_client_cnt_share_prod_shift_2                          1676
# oborot_kredit_share_prod_shift_2                             1978
# invest_kredit_share_prod_shift_2                             5520
# overdraft_kredit_share_prod_shift_2                          4874
# proekt_finans_share_prod_shift_2                            19692
# products_lizing_share_prod_shift_2                           4128
# obsluzh_rts_rur_share_prod_shift_2                           1752
# obsluzh_rts_val_share_prod_shift_2                           4005
# spec_acc_share_prod_shift_2                                  8293
# deposit_share_prod_shift_2                                   2169
# veksel_share_prod_shift_2                                   13050
# deposit_sertificat_share_prod_shift_2                       19813
# inkass_share_prod_shift_2                                    5369
# samoinkass_share_prod_shift_2                                1848
# zarplat_projects_share_prod_shift_2                          1938
# acquiring_torg_share_prod_shift_2                            1860
# acquiring_mobile_share_prod_shift_2                          7471
# acreditiv_share_prod_shift_2                                17123
# valuta_control_share_prod_shift_2                            2317
# garantee_kontract_share_prod_shift_2                         8417
# garantee_gos_share_prod_shift_2                             19834
# garantee_other_share_prod_shift_2                           16561
# arenda_seyf_share_prod_shift_2                              19056
# dbo_share_prod_shift_2                                       1698
# corporate_cards_share_prod_shift_2                           1904
# cash_management_share_prod_shift_2                           9720
# bank_straxovanie_imush_share_prod_shift_2                    2294
# bank_straxovanie_lich_share_prod_shift_2                     2425
# bank_straxovanie_otvet_share_prod_shift_2                   18349
# einvoicing_share_prod_shift_2                                2011
# factoring_share_prod_shift_2                                19166
# konversion_share_prod_shift_2                                5831
# ns_servis_share_prod_shift_2                                17386
# ns_terminal_share_prod_shift_2                               6412
# work_sreda_share_prod_shift_2                               19814
# ns_sait_share_prod_shift_2                                  14915
# ns_garant_share_prod_shift_2                                18120
# pfi_share_prod_shift_2                                      19840
# dcd_share_prod_shift_2                                      19757
# inkass_ratio_share_prod_shift_2                              5369
# bank_straxovanie_imush_ratio_share_prod_shift_2              2294
# einvoicing_ratio_share_prod_shift_2                          2011
# deposit_sertificat_ratio_share_prod_shift_2                 19813
# acquiring_torg_ratio_share_prod_shift_2                      1860
# konversion_ratio_share_prod_shift_2                          5831
# overdraft_kredit_ratio_share_prod_shift_2                    4874
# work_sreda_ratio_share_prod_shift_2                         19814
# samoinkass_ratio_share_prod_shift_2                          1848
# factoring_ratio_share_prod_shift_2                          19166
# garantee_gos_ratio_share_prod_shift_2                       19834
# obsluzh_rts_val_ratio_share_prod_shift_2                     4005
# invest_kredit_ratio_share_prod_shift_2                       5520
# corporate_cards_ratio_share_prod_shift_2                     1904
# acreditiv_ratio_share_prod_shift_2                          17123
# deposit_ratio_share_prod_shift_2                             2169
# oborot_kredit_ratio_share_prod_shift_2                       1978
# cash_management_ratio_share_prod_shift_2                     9720
# ns_terminal_ratio_share_prod_shift_2                         6412
# ns_garant_ratio_share_prod_shift_2                          18120
# spec_acc_ratio_share_prod_shift_2                            8293
# products_lizing_ratio_share_prod_shift_2                     4128
# dbo_ratio_share_prod_shift_2                                 1698
# bank_straxovanie_lich_ratio_share_prod_shift_2               2425
# veksel_ratio_share_prod_shift_2                             13050
# dcd_ratio_share_prod_shift_2                                19757
# acquiring_mobile_ratio_share_prod_shift_2                    7471
# bank_straxovanie_otvet_ratio_share_prod_shift_2             18349
# garantee_other_ratio_share_prod_shift_2                     16561
# pfi_ratio_share_prod_shift_2                                19840
# proekt_finans_ratio_share_prod_shift_2                      19692
# arenda_seyf_ratio_share_prod_shift_2                        19056
# valuta_control_ratio_share_prod_shift_2                      2317
# zarplat_projects_ratio_share_prod_shift_2                    1938
# garantee_kontract_ratio_share_prod_shift_2                   8417
# ns_servis_ratio_share_prod_shift_2                          17386
# ns_sait_ratio_share_prod_shift_2                            14915
# obsluzh_rts_rur_ratio_share_prod_shift_2                     1752
# total_client_cnt_share_prod_shift_3                          2140
# oborot_kredit_share_prod_shift_3                             2479
# invest_kredit_share_prod_shift_3                             4392
# overdraft_kredit_share_prod_shift_3                          5734
# proekt_finans_share_prod_shift_3                            19702
# products_lizing_share_prod_shift_3                           4800
# obsluzh_rts_rur_share_prod_shift_3                           2220
# obsluzh_rts_val_share_prod_shift_3                           4557
# spec_acc_share_prod_shift_3                                  8867
# deposit_share_prod_shift_3                                   2721
# veksel_share_prod_shift_3                                   13334
# deposit_sertificat_share_prod_shift_3                       19821
# inkass_share_prod_shift_3                                    5759
# samoinkass_share_prod_shift_3                                2320
# zarplat_projects_share_prod_shift_3                          2461
# acquiring_torg_share_prod_shift_3                            2374
# acquiring_mobile_share_prod_shift_3                          8203
# acreditiv_share_prod_shift_3                                17375
# valuta_control_share_prod_shift_3                            2834
# garantee_kontract_share_prod_shift_3                         9025
# garantee_gos_share_prod_shift_3                             19819
# garantee_other_share_prod_shift_3                           16794
# arenda_seyf_share_prod_shift_3                              19096
# dbo_share_prod_shift_3                                       2172
# corporate_cards_share_prod_shift_3                           2437
# cash_management_share_prod_shift_3                          10112
# bank_straxovanie_imush_share_prod_shift_3                    2961
# bank_straxovanie_lich_share_prod_shift_3                     2942
# bank_straxovanie_otvet_share_prod_shift_3                   18436
# einvoicing_share_prod_shift_3                                2528
# factoring_share_prod_shift_3                                19192
# konversion_share_prod_shift_3                                6435
# ns_servis_share_prod_shift_3                                17595
# ns_terminal_share_prod_shift_3                               8429
# work_sreda_share_prod_shift_3                               19815
# ns_sait_share_prod_shift_3                                  15145
# ns_garant_share_prod_shift_3                                18223
# pfi_share_prod_shift_3                                      19843
# dcd_share_prod_shift_3                                      19754
# inkass_ratio_share_prod_shift_3                              5759
# bank_straxovanie_imush_ratio_share_prod_shift_3              2961
# einvoicing_ratio_share_prod_shift_3                          2528
# deposit_sertificat_ratio_share_prod_shift_3                 19821
# acquiring_torg_ratio_share_prod_shift_3                      2374
# konversion_ratio_share_prod_shift_3                          6435
# overdraft_kredit_ratio_share_prod_shift_3                    5734
# work_sreda_ratio_share_prod_shift_3                         19815
# samoinkass_ratio_share_prod_shift_3                          2320
# factoring_ratio_share_prod_shift_3                          19192
# garantee_gos_ratio_share_prod_shift_3                       19819
# obsluzh_rts_val_ratio_share_prod_shift_3                     4557
# invest_kredit_ratio_share_prod_shift_3                       4392
# corporate_cards_ratio_share_prod_shift_3                     2437
# acreditiv_ratio_share_prod_shift_3                          17375
# deposit_ratio_share_prod_shift_3                             2721
# oborot_kredit_ratio_share_prod_shift_3                       2479
# cash_management_ratio_share_prod_shift_3                    10112
# ns_terminal_ratio_share_prod_shift_3                         8429
# ns_garant_ratio_share_prod_shift_3                          18223
# spec_acc_ratio_share_prod_shift_3                            8867
# products_lizing_ratio_share_prod_shift_3                     4800
# dbo_ratio_share_prod_shift_3                                 2172
# bank_straxovanie_lich_ratio_share_prod_shift_3               2942
# veksel_ratio_share_prod_shift_3                             13334
# dcd_ratio_share_prod_shift_3                                19754
# acquiring_mobile_ratio_share_prod_shift_3                    8203
# bank_straxovanie_otvet_ratio_share_prod_shift_3             18436
# garantee_other_ratio_share_prod_shift_3                     16794
# pfi_ratio_share_prod_shift_3                                19843
# proekt_finans_ratio_share_prod_shift_3                      19702
# arenda_seyf_ratio_share_prod_shift_3                        19096
# valuta_control_ratio_share_prod_shift_3                      2834
# zarplat_projects_ratio_share_prod_shift_3                    2461
# garantee_kontract_ratio_share_prod_shift_3                   9025
# ns_servis_ratio_share_prod_shift_3                          17595
# ns_sait_ratio_share_prod_shift_3                            15145
# obsluzh_rts_rur_ratio_share_prod_shift_3                     2220
# days_between                                                19606
# is_previous_sold                                            19606
# days_between_km_dealdiff                                    17088
# is_previous_sold_km_dealdiff                                17088
#
#                                                  train_null_ratio
# tb                                                       0.005035
# gosb                                                     0.020141
# product                                                  0.000000
# product_group                                            0.000000
# days_cr_q_end                                            0.000000
# segment_client                                           0.000000
# priority_client                                          0.000000
# sum_sold                                                16.213494
# sum_sold_cumulate                                       16.213494
# sum_refused                                             16.213494
# sum_refused_cumulate                                    16.213494
# sum_sold_total                                          16.213494
# sum_sold_total_cumulate                                 16.213494
# sum_refused_total                                       16.213494
# sum_refused_tota_cumulate                               16.213494
# sum_sold_company_shift_1                                92.270896
# sum_sold_cumulate_company_shift_1                       92.270896
# sum_refused_company_shift_1                             92.270896
# sum_refused_cumulate_company_shift_1                    92.270896
# sum_sold_total_company_shift_1                          92.270896
# sum_sold_total_cumulate_company_shift_1                 92.270896
# sum_refused_total_company_shift_1                       92.270896
# sum_refused_total_cumulate                              92.270896
# sum_sold_km_shift_2                                     16.334340
# sum_sold_cumulate_km_shift_2                            16.334340
# sum_refused_km_shift_2                                  16.334340
# sum_refused_cumulate_km_shift_2                         16.334340
# sum_sold_total_km_shift_2                               16.334340
# sum_sold_total_cumulate_km_shift_2                      16.334340
# sum_refused_total_km_shift_2                            16.334340
# sum_refused_tota_cumulate_km_shift_2                    16.334340
# sum_sold_company_shift_2                                92.301108
# sum_sold_cumulate_company_shift_2                       92.301108
# sum_refused_company_shift_2                             92.301108
# sum_refused_cumulate_company_shift_2                    92.301108
# sum_sold_total_company_shift_2                          92.301108
# sum_sold_total_cumulate_company_shift_2                 92.301108
# sum_refused_total_company_shift_2                       92.301108
# sum_refused_total_cumulate_company_shift_2              92.301108
# sum_sold_km_shift_3                                     16.450151
# sum_sold_cumulate_km_shift_3                            16.450151
# sum_refused_km_shift_3                                  16.450151
# sum_refused_cumulate_km_shift_3                         16.450151
# sum_sold_total_km_shift_3                               16.450151
# sum_sold_total_cumulate_km_shift_3                      16.450151
# sum_refused_total_km_shift_3                            16.450151
# sum_refused_tota_cumulate_km_shift_3                    16.450151
# sum_sold_company_shift_3                                92.321249
# sum_sold_cumulate_company_shift_3                       92.321249
# sum_refused_company_shift_3                             92.321249
# sum_refused_cumulate_company_shift_3                    92.321249
# sum_sold_total_company_shift_3                          92.321249
# sum_sold_total_cumulate_company_shift_3                 92.321249
# sum_refused_total_company_shift_3                       92.321249
# sum_refused_total_cumulate_company_shift_3              92.321249
# sum_sold_agg_km_shift_1                                  5.659617
# sum_sold_cumulate_agg_km_shift_1                         5.659617
# sum_refused_agg_km_shift_1                               5.659617
# sum_refused_cumulate_agg_km_shift_1                      5.659617
# sum_sold_total_agg_km_shift_1                            5.659617
# sum_sold_total_cumulate_agg_km_shift_1                   5.659617
# sum_refused_total_agg_km_shift_1                         5.659617
# sum_refused_tota_cumulate_agg_km_shift_1                 5.659617
# sum_sold_agg_company_shift_1                            87.064451
# sum_sold_cumulate_agg_company_shift_1                   87.064451
# sum_refused_agg_company_shift_1                         87.064451
# sum_refused_cumulate_agg_company_shift_1                87.064451
# sum_sold_total_agg_company_shift_1                      87.064451
# sum_sold_total_cumulate_agg_company_shift_1             87.064451
# sum_refused_total_agg_company_shift_1                   87.064451
# sum_refused_total_cumulate_agg_company_shift_1          87.064451
# sum_sold_agg_km_shift_2                                  5.790534
# sum_sold_cumulate_agg_km_shift_2                         5.790534
# sum_refused_agg_km_shift_2                               5.790534
# sum_refused_cumulate_agg_km_shift_2                      5.790534
# sum_sold_total_agg_km_shift_2                            5.790534
# sum_sold_total_cumulate_agg_km_shift_2                   5.790534
# sum_refused_total_agg_km_shift_2                         5.790534
# sum_refused_tota_cumulate_agg_km_shift_2                 5.790534
# sum_sold_agg_company_shift_2                            87.099698
# sum_sold_cumulate_agg_company_shift_2                   87.099698
# sum_refused_agg_company_shift_2                         87.099698
# sum_refused_cumulate_agg_company_shift_2                87.099698
# sum_sold_total_agg_company_shift_2                      87.099698
# sum_sold_total_cumulate_agg_company_shift_2             87.099698
# sum_refused_total_agg_company_shift_2                   87.099698
# sum_refused_total_cumulate_agg_company_shift_2          87.099698
# sum_sold_agg_km_shift_3                                  5.921450
# sum_sold_cumulate_agg_km_shift_3                         5.921450
# sum_refused_agg_km_shift_3                               5.921450
# sum_refused_cumulate_agg_km_shift_3                      5.921450
# sum_sold_total_agg_km_shift_3                            5.921450
# sum_sold_total_cumulate_agg_km_shift_3                   5.921450
# sum_refused_total_agg_km_shift_3                         5.921450
# sum_refused_tota_cumulate_agg_km_shift_3                 5.921450
# sum_sold_agg_company_shift_3                            87.119839
# sum_sold_cumulate_agg_company_shift_3                   87.119839
# sum_refused_agg_company_shift_3                         87.119839
# sum_refused_cumulate_agg_company_shift_3                87.119839
# sum_sold_total_agg_company_shift_3                      87.119839
# sum_sold_total_cumulate_agg_company_shift_3             87.119839
# sum_refused_total_agg_company_shift_3                   87.119839
# sum_refused_total_cumulate_agg_company_shift_3          87.119839
# total_client_cnt                                         5.453172
# oborot_kredit                                            6.968781
# invest_kredit                                           43.157100
# overdraft_kredit                                        19.813696
# proekt_finans                                           99.169184
# products_lizing                                         16.762336
# obsluzh_rts_rur                                          5.830816
# obsluzh_rts_val                                         16.968781
# spec_acc                                                39.415911
# deposit                                                  7.960725
# veksel                                                  65.281974
# deposit_sertificat                                      99.733132
# inkass                                                  24.375629
# samoinkass                                               6.278953
# zarplat_projects                                         6.737160
# acquiring_torg                                           6.394763
# acquiring_mobile                                        33.383686
# acreditiv                                               85.619335
# valuta_control                                           8.368580
# garantee_kontract                                       38.348439
# garantee_gos                                            99.904330
# garantee_other                                          81.858006
# arenda_seyf                                             95.609265
# dbo                                                      5.543807
# corporate_cards                                          6.520645
# cash_management                                         46.067472
# bank_straxovanie_imush                                   8.152064
# bank_straxovanie_lich                                    8.766365
# bank_straxovanie_otvet                                  91.465257
# einvoicing                                               7.124874
# factoring                                               96.289023
# konversion                                              26.002014
# ns_servis                                               85.503525
# ns_terminal                                             28.298087
# work_sreda                                              99.859013
# ns_sait                                                 74.244713
# ns_garant                                               90.342397
# pfi                                                     99.909366
# dcd                                                     99.481370
# inkass_ratio                                            24.375629
# bank_straxovanie_imush_ratio                             8.152064
# einvoicing_ratio                                         7.124874
# deposit_sertificat_ratio                                99.733132
# acquiring_torg_ratio                                     6.394763
# konversion_ratio                                        26.002014
# overdraft_kredit_ratio                                  19.813696
# work_sreda_ratio                                        99.859013
# samoinkass_ratio                                         6.278953
# factoring_ratio                                         96.289023
# garantee_gos_ratio                                      99.904330
# obsluzh_rts_val_ratio                                   16.968781
# invest_kredit_ratio                                     43.157100
# corporate_cards_ratio                                    6.520645
# acreditiv_ratio                                         85.619335
# deposit_ratio                                            7.960725
# oborot_kredit_ratio                                      6.968781
# cash_management_ratio                                   46.067472
# ns_terminal_ratio                                       28.298087
# ns_garant_ratio                                         90.342397
# spec_acc_ratio                                          39.415911
# products_lizing_ratio                                   16.762336
# dbo_ratio                                                5.543807
# bank_straxovanie_lich_ratio                              8.766365
# veksel_ratio                                            65.281974
# dcd_ratio                                               99.481370
# acquiring_mobile_ratio                                  33.383686
# bank_straxovanie_otvet_ratio                            91.465257
# garantee_other_ratio                                    81.858006
# pfi_ratio                                               99.909366
# proekt_finans_ratio                                     99.169184
# arenda_seyf_ratio                                       95.609265
# valuta_control_ratio                                     8.368580
# zarplat_projects_ratio                                   6.737160
# garantee_kontract_ratio                                 38.348439
# ns_servis_ratio                                         85.503525
# ns_sait_ratio                                           74.244713
# obsluzh_rts_rur_ratio                                    5.830816
# total_client_cnt_share_prod_shift_2                      8.439074
# oborot_kredit_share_prod_shift_2                         9.959718
# invest_kredit_share_prod_shift_2                        27.794562
# overdraft_kredit_share_prod_shift_2                     24.541793
# proekt_finans_share_prod_shift_2                        99.154079
# products_lizing_share_prod_shift_2                      20.785498
# obsluzh_rts_rur_share_prod_shift_2                       8.821752
# obsluzh_rts_val_share_prod_shift_2                      20.166163
# spec_acc_share_prod_shift_2                             41.757301
# deposit_share_prod_shift_2                              10.921450
# veksel_share_prod_shift_2                               65.709970
# deposit_sertificat_share_prod_shift_2                   99.763343
# inkass_share_prod_shift_2                               27.034240
# samoinkass_share_prod_shift_2                            9.305136
# zarplat_projects_share_prod_shift_2                      9.758308
# acquiring_torg_share_prod_shift_2                        9.365559
# acquiring_mobile_share_prod_shift_2                     37.618328
# acreditiv_share_prod_shift_2                            86.218530
# valuta_control_share_prod_shift_2                       11.666667
# garantee_kontract_share_prod_shift_2                    42.381672
# garantee_gos_share_prod_shift_2                         99.869084
# garantee_other_share_prod_shift_2                       83.388721
# arenda_seyf_share_prod_shift_2                          95.951662
# dbo_share_prod_shift_2                                   8.549849
# corporate_cards_share_prod_shift_2                       9.587110
# cash_management_share_prod_shift_2                      48.942598
# bank_straxovanie_imush_share_prod_shift_2               11.550856
# bank_straxovanie_lich_share_prod_shift_2                12.210473
# bank_straxovanie_otvet_share_prod_shift_2               92.391742
# einvoicing_share_prod_shift_2                           10.125881
# factoring_share_prod_shift_2                            96.505539
# konversion_share_prod_shift_2                           29.360524
# ns_servis_share_prod_shift_2                            87.542800
# ns_terminal_share_prod_shift_2                          32.286002
# work_sreda_share_prod_shift_2                           99.768379
# ns_sait_share_prod_shift_2                              75.100705
# ns_garant_share_prod_shift_2                            91.238671
# pfi_share_prod_shift_2                                  99.899295
# dcd_share_prod_shift_2                                  99.481370
# inkass_ratio_share_prod_shift_2                         27.034240
# bank_straxovanie_imush_ratio_share_prod_shift_2         11.550856
# einvoicing_ratio_share_prod_shift_2                     10.125881
# deposit_sertificat_ratio_share_prod_shift_2             99.763343
# acquiring_torg_ratio_share_prod_shift_2                  9.365559
# konversion_ratio_share_prod_shift_2                     29.360524
# overdraft_kredit_ratio_share_prod_shift_2               24.541793
# work_sreda_ratio_share_prod_shift_2                     99.768379
# samoinkass_ratio_share_prod_shift_2                      9.305136
# factoring_ratio_share_prod_shift_2                      96.505539
# garantee_gos_ratio_share_prod_shift_2                   99.869084
# obsluzh_rts_val_ratio_share_prod_shift_2                20.166163
# invest_kredit_ratio_share_prod_shift_2                  27.794562
# corporate_cards_ratio_share_prod_shift_2                 9.587110
# acreditiv_ratio_share_prod_shift_2                      86.218530
# deposit_ratio_share_prod_shift_2                        10.921450
# oborot_kredit_ratio_share_prod_shift_2                   9.959718
# cash_management_ratio_share_prod_shift_2                48.942598
# ns_terminal_ratio_share_prod_shift_2                    32.286002
# ns_garant_ratio_share_prod_shift_2                      91.238671
# spec_acc_ratio_share_prod_shift_2                       41.757301
# products_lizing_ratio_share_prod_shift_2                20.785498
# dbo_ratio_share_prod_shift_2                             8.549849
# bank_straxovanie_lich_ratio_share_prod_shift_2          12.210473
# veksel_ratio_share_prod_shift_2                         65.709970
# dcd_ratio_share_prod_shift_2                            99.481370
# acquiring_mobile_ratio_share_prod_shift_2               37.618328
# bank_straxovanie_otvet_ratio_share_prod_shift_2         92.391742
# garantee_other_ratio_share_prod_shift_2                 83.388721
# pfi_ratio_share_prod_shift_2                            99.899295
# proekt_finans_ratio_share_prod_shift_2                  99.154079
# arenda_seyf_ratio_share_prod_shift_2                    95.951662
# valuta_control_ratio_share_prod_shift_2                 11.666667
# zarplat_projects_ratio_share_prod_shift_2                9.758308
# garantee_kontract_ratio_share_prod_shift_2              42.381672
# ns_servis_ratio_share_prod_shift_2                      87.542800
# ns_sait_ratio_share_prod_shift_2                        75.100705
# obsluzh_rts_rur_ratio_share_prod_shift_2                 8.821752
# total_client_cnt_share_prod_shift_3                     10.775428
# oborot_kredit_share_prod_shift_3                        12.482377
# invest_kredit_share_prod_shift_3                        22.114804
# overdraft_kredit_share_prod_shift_3                     28.872105
# proekt_finans_share_prod_shift_3                        99.204431
# products_lizing_share_prod_shift_3                      24.169184
# obsluzh_rts_rur_share_prod_shift_3                      11.178248
# obsluzh_rts_val_share_prod_shift_3                      22.945619
# spec_acc_share_prod_shift_3                             44.647533
# deposit_share_prod_shift_3                              13.700906
# veksel_share_prod_shift_3                               67.139980
# deposit_sertificat_share_prod_shift_3                   99.803625
# inkass_share_prod_shift_3                               28.997986
# samoinkass_share_prod_shift_3                           11.681772
# zarplat_projects_share_prod_shift_3                     12.391742
# acquiring_torg_share_prod_shift_3                       11.953676
# acquiring_mobile_share_prod_shift_3                     41.304129
# acreditiv_share_prod_shift_3                            87.487412
# valuta_control_share_prod_shift_3                       14.269889
# garantee_kontract_share_prod_shift_3                    45.443102
# garantee_gos_share_prod_shift_3                         99.793555
# garantee_other_share_prod_shift_3                       84.561934
# arenda_seyf_share_prod_shift_3                          96.153072
# dbo_share_prod_shift_3                                  10.936556
# corporate_cards_share_prod_shift_3                      12.270896
# cash_management_share_prod_shift_3                      50.916415
# bank_straxovanie_imush_share_prod_shift_3               14.909366
# bank_straxovanie_lich_share_prod_shift_3                14.813696
# bank_straxovanie_otvet_share_prod_shift_3               92.829809
# einvoicing_share_prod_shift_3                           12.729104
# factoring_share_prod_shift_3                            96.636455
# konversion_share_prod_shift_3                           32.401813
# ns_servis_share_prod_shift_3                            88.595166
# ns_terminal_share_prod_shift_3                          42.442095
# work_sreda_share_prod_shift_3                           99.773414
# ns_sait_share_prod_shift_3                              76.258812
# ns_garant_share_prod_shift_3                            91.757301
# pfi_share_prod_shift_3                                  99.914401
# dcd_share_prod_shift_3                                  99.466264
# inkass_ratio_share_prod_shift_3                         28.997986
# bank_straxovanie_imush_ratio_share_prod_shift_3         14.909366
# einvoicing_ratio_share_prod_shift_3                     12.729104
# deposit_sertificat_ratio_share_prod_shift_3             99.803625
# acquiring_torg_ratio_share_prod_shift_3                 11.953676
# konversion_ratio_share_prod_shift_3                     32.401813
# overdraft_kredit_ratio_share_prod_shift_3               28.872105
# work_sreda_ratio_share_prod_shift_3                     99.773414
# samoinkass_ratio_share_prod_shift_3                     11.681772
# factoring_ratio_share_prod_shift_3                      96.636455
# garantee_gos_ratio_share_prod_shift_3                   99.793555
# obsluzh_rts_val_ratio_share_prod_shift_3                22.945619
# invest_kredit_ratio_share_prod_shift_3                  22.114804
# corporate_cards_ratio_share_prod_shift_3                12.270896
# acreditiv_ratio_share_prod_shift_3                      87.487412
# deposit_ratio_share_prod_shift_3                        13.700906
# oborot_kredit_ratio_share_prod_shift_3                  12.482377
# cash_management_ratio_share_prod_shift_3                50.916415
# ns_terminal_ratio_share_prod_shift_3                    42.442095
# ns_garant_ratio_share_prod_shift_3                      91.757301
# spec_acc_ratio_share_prod_shift_3                       44.647533
# products_lizing_ratio_share_prod_shift_3                24.169184
# dbo_ratio_share_prod_shift_3                            10.936556
# bank_straxovanie_lich_ratio_share_prod_shift_3          14.813696
# veksel_ratio_share_prod_shift_3                         67.139980
# dcd_ratio_share_prod_shift_3                            99.466264
# acquiring_mobile_ratio_share_prod_shift_3               41.304129
# bank_straxovanie_otvet_ratio_share_prod_shift_3         92.829809
# garantee_other_ratio_share_prod_shift_3                 84.561934
# pfi_ratio_share_prod_shift_3                            99.914401
# proekt_finans_ratio_share_prod_shift_3                  99.204431
# arenda_seyf_ratio_share_prod_shift_3                    96.153072
# valuta_control_ratio_share_prod_shift_3                 14.269889
# zarplat_projects_ratio_share_prod_shift_3               12.391742
# garantee_kontract_ratio_share_prod_shift_3              45.443102
# ns_servis_ratio_share_prod_shift_3                      88.595166
# ns_sait_ratio_share_prod_shift_3                        76.258812
# obsluzh_rts_rur_ratio_share_prod_shift_3                11.178248
# days_between                                            98.721047
# is_previous_sold                                        98.721047
# days_between_km_dealdiff                                86.042296
# is_previous_sold_km_dealdiff                            86.042296

# %%
if FLAG == 'test/train':
    dropnull=null_compare[null_compare['train_null_ratio']>90.].index.tolist()
    joblib.dump(dropnull, get_path('pkl_store','dropnullcol_lst.pkl'))
elif FLAG == 'validate':
    dropnull=joblib.load(get_path('pkl_store','dropnullcol_lst.pkl'))

# %%
df = df.drop(dropnull, axis=1, errors='ignore')

# %%
df.shape
# Out:
# (19860, 268)

# %%
if FLAG == 'test/train':
    df.to_pickle(get_path('pkl_store', 'total_dataset_unencoded.pkl'))
elif FLAG == 'validate':
    df.to_pickle(get_path('pkl_store', 'test_dataset_unencoded.pkl'))

# %% [markdown]
# ## Label encoding

# %%
from label_encoder import SoftLabelEncoder

# %%
label_encoders = {}
for col in df.dtypes[df.dtypes == 'O'].index:
    le = SoftLabelEncoder()
    df[col] = le.fit_transform(df[col].fillna('NaN'))
    label_encoders[col] = le

# %%
df.to_pickle(get_path('pkl_store', 'total_dataset_encod.pkl'))

# %%
joblib.dump(label_encoders, get_path('pkl_store', 'label_encoders.pkl'))
# Out:
# ['pkl_store/label_encoders.pkl']

# %%
col_name='product_group'
le = joblib.load(get_path('pkl_store', 'label_encoders.pkl'))[col_name]

# %%
le.get_keys(), le.get_labels()
# Out:
# (dict_keys(['ВНЕШНИЙ МАЛЫЙ СМАРТ', 'ИНФОРМАЦИОННЫЕ УСЛУГИ', 'ФАКТОРИНГ', 'ВЕКСЕЛЯ', 'CASH MANAGEMENT', 'ПАКЕТЫ УСЛУГ', 'ИНВЕСТИЦИОННЫЕ ПРОДУКТЫ', 'БИЗНЕС-КАРТА', 'КАРТА ДАЛЬНОБОЙЩИКА', 'КОНВЕРСИОННЫЕ ОПЕРАЦИИ', 'КРЕДИТОВАНИЕ', 'ВНЕШНИЙ МИКРО СМАРТ', 'ЗАРПЛАТНЫЕ ПРОЕКТЫ', 'АРЕНДА СЕЙФОВ', 'ЭКВАЙРИНГ', 'РОЗНИЧНЫЕ ПРОДУКТЫ', 'ИНКАССАЦИЯ', 'ДЕПОЗИТНЫЕ СЕРТИФИКАТЫ', 'ВАЛЮТНЫЙ КОНТРОЛЬ', 'СТРАХОВАНИЕ', 'ДОСТАВКА ДЕНЕЖНОЙ НАЛИЧНОСТИ И ЦЕННОСТЕЙ', 'ДЕЛОВАЯ СРЕДА', 'ЭВОТОР', 'РКО', 'ТЕХНИЧЕСКИЕ ПРОДУКТЫ', 'КРЕДИТНАЯ БИЗНЕС-КАРТА', 'ПРИЕМ ПЛАТЕЖЕЙ ФИЗ. ЛИЦ', 'БАНКОВСКАЯ ГАРАНТИЯ', 'ДИСТАНЦИОННОЕ ОБСЛУЖИВАНИЕ', 'ПРОДУКТЫ ПРИВЛЕЧЕНИЯ СРЕДСТВ', 'ПРЕМИАЛЬНАЯ БИЗНЕС-КАРТА', 'ДОКУМЕНТАРНЫЕ ОПЕРАЦИИ']),
#  dict_values([6, 16, 29, 5, 0, 21, 14, 3, 17, 18, 20, 7, 13, 1, 31, 26, 15, 9, 4, 27, 12, 8, 30, 25, 28, 19, 23, 2, 10, 24, 22, 11]))

# %%
product_group_lables = pd.DataFrame({'label': list(le.get_keys()), 'value': list(le.get_labels())})
product_group_lables = product_group_lables.set_index('value')
product_group_lables

# %%
product_group_lables.loc[0]['label'],  product_group_lables.iloc[0]['label']
# Out:
# ('CASH MANAGEMENT', 'ВНЕШНИЙ МАЛЫЙ СМАРТ')

# %%
null_compare['train_null_ratio'].mean()
# Out:
# 45.01372532639097
